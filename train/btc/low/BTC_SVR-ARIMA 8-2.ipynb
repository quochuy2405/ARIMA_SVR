# %% [markdown]
# ## 1. Quá trình dự báo trên mô hình ARIMA

# %% [markdown]
# # Thêm thư viện

# %%
import pandas as pd
import warnings
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import pmdarima as pmd
import numpy as np
from sklearn.svm import SVR
from pmdarima.arima import auto_arima
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import StandardScaler
from sklearn.utils import column_or_1d
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
warnings.filterwarnings('ignore')

# %% [markdown]
# # Nạp dữ liệu từ file csv

# %%
df = pd.read_csv('../../../data/clean/btc.csv')
df.pop('volume')
df.pop('high')
df.pop('open')
df.pop('low')
df.pop('adjclose')
df = df.reset_index()
df['formatted_date'] = pd.to_datetime(df['formatted_date']).values.astype(np.int64)
df.set_index("formatted_date",inplace=True)
df.pop('index')
df.pop('Unnamed: 0')
df_low = df['low'].values.reshape(-1, 1)

df
# Out:
#                             close
# formatted_date
# 1546300800000000000   3943.409424
# 1546387200000000000   3836.741211
# 1546473600000000000   3857.717529
# 1546560000000000000   3845.194580
# 1546646400000000000   4076.632568
# ...                           ...
# 1681948800000000000  27276.910156
# 1682035200000000000  27817.500000
# 1682121600000000000  27591.384766
# 1682208000000000000  27525.339844
# 1682294400000000000  27438.240234
#
# [1575 rows x 1 columns]

# %% [markdown]
# # Chuẩn hóa dữ liệu

# %%
arima_sc = StandardScaler()

df_scaled = df.copy()
df_scaled['low'] = arima_sc.fit_transform(df_low)
df_scaled
# Out:
#                         close
# formatted_date
# 1546300800000000000 -1.160522
# 1546387200000000000 -1.166824
# 1546473600000000000 -1.165585
# 1546560000000000000 -1.166324
# 1546646400000000000 -1.152651
# ...                       ...
# 1681948800000000000  0.218032
# 1682035200000000000  0.249971
# 1682121600000000000  0.236612
# 1682208000000000000  0.232710
# 1682294400000000000  0.227564
#
# [1575 rows x 1 columns]

# %% [markdown]
# # Vẽ đồ thị

# %%
# Thư viện vẽ đồ thị
formatter = ticker.StrMethodFormatter('${x:,.0f}')

title = 'Bitcoin Price'
ylabel = 'USD'
xlabel = 'Date'

ax = df['low'].plot(figsize=(16, 9), title=title)
ax.autoscale(axis='x', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.yaxis.set_major_formatter(formatter)
ax.grid(True)

# %% [markdown]
# # Tách dữ liệu thành tập train và test

# %%
train, test = df_scaled[:(int)(len(df_scaled) * 1)], df_scaled[(int)(len(df_scaled) * 1):]
index_test = df_scaled.index[:(int)(len(df_scaled) * 1)]
print('train shape: ', train.shape)
print('test shape: ', test.shape)
# Out:
# train shape:  (1575, 1)
# test shape:  (0, 1)

# %% [markdown]
# # Hàm kiểm định chuỗi dừng

# %%
def adf_test(series, title=''):
    """
    Pass in a time series and an optional title, returns an ADF report
    """
    print(f'Augmented Dickey-Fuller Test: {title}')
    # .dropna() handles differenced data
    result = adfuller(series.dropna(), autolag='AIC')

    labels = ['ADF test statistic', 'p-value',
              'Number of lags used', 'Number of observations']
    out = pd.Series(result[0:4], index=labels)

    for key, val in result[4].items():
        out[f'critical value ({key})'] = val

    # .to_string() removes the line "dtype: float64"
    print(out.to_string())

    if result[1] <= 0.05:
        print("Strong evidence against the null hypothesis")
        print("Reject the null hypothesis")
        print("Data has no unit root and is stationary")
    else:
        print("Weak evidence against the null hypothesis")
        print("Fail to reject the null hypothesis")
        print("Data has a unit root and is non stationary")

# %% [markdown]
# # Kiểm định tính dừng của chuỗi

# %%
adf_test(train['low'],'Bitcoin Price')
# Out:
# Augmented Dickey-Fuller Test: Bitcoin Price
# ADF test statistic          -1.592909
# p-value                      0.487155
# Number of lags used         24.000000
# Number of observations    1550.000000
# critical value (1%)         -3.434576
# critical value (5%)         -2.863406
# critical value (10%)        -2.567764
# Weak evidence against the null hypothesis
# Fail to reject the null hypothesis
# Data has a unit root and is non stationary

# %% [markdown]
# nhận thấy p-value > 0.05, do đó chuỗi không phải là chuỗi dừng

# %% [markdown]
# # Tính sai phân bậc 1 (d = 1) của chuỗi để kiểm định tính dừng

# %%
diff_1 = train.dropna().diff()
diff_1.plot(figsize=(12,5))
# Out:
# <Axes: xlabel='formatted_date'>

# %% [markdown]
# # Kiểm định tính dừng của chuỗi tại sai phân bậc 1

# %%
adf_test(diff_1, 'Bitcoin Price First Difference')
# Out:
# Augmented Dickey-Fuller Test: Bitcoin Price First Difference
# ADF test statistic       -7.811727e+00
# p-value                   7.040552e-12
# Number of lags used       2.300000e+01
# Number of observations    1.550000e+03
# critical value (1%)      -3.434576e+00
# critical value (5%)      -2.863406e+00
# critical value (10%)     -2.567764e+00
# Strong evidence against the null hypothesis
# Reject the null hypothesis
# Data has no unit root and is stationary

# %% [markdown]
# Nhận thấy p-value < 0.05, do đó chuỗi có tính dừng tại sai phân bậc 1

# %%
def ArimaModel(timeseriesarray):
    autoarima_model = pmd.auto_arima(timeseriesarray, 
                              test="adf",
                              seasonal=False,
                              trace=True)
    return autoarima_model

# %%
import pickle
arima_model = ArimaModel(train)
arima_model.summary()
with open("../../../models/low/arima_model.pkl", "wb") as f:
        pickle.dump(arima_model, f)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-4175.193, Time=0.73 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-4180.647, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-4180.049, Time=0.30 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-4180.022, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-4182.348, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-4178.091, Time=0.18 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 1.580 seconds

# %% [markdown]
# # Dự đoán trên tập test

# %%
pred = arima_model.predict(len(train))
pred
# Out:
# 1575    0.227564
# 1576    0.227564
# 1577    0.227564
# 1578    0.227564
# 1579    0.227564
#           ...
# 3145    0.227564
# 3146    0.227564
# 3147    0.227564
# 3148    0.227564
# 3149    0.227564
# Length: 1575, dtype: float64

# %% [markdown]
# # Biến đổi giá trị dự đoán và thực tế về miền giá trị ban đầu

# %%
inv_test = arima_sc.inverse_transform(train.values.reshape(-1, 1))
inv_pred = arima_sc.inverse_transform(column_or_1d(pred).reshape(-1, 1))

# %% [markdown]
# # Vẽ đồ thị cho tập test và kết quả dự đoán

# %%
pred_series = pd.Series(pred, index=index_test)

plt.figure(figsize=(16, 9))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(inv_test, 'blue', label='Actual data')
plt.plot(inv_pred, 'orange', label='Predicted data')
plt.legend()

# %% [markdown]
# # Đánh giá mô hình

# %%
mae = mean_absolute_error(inv_test, inv_pred)
mape = mean_absolute_percentage_error(inv_test, inv_pred)
mse = mean_squared_error(inv_test, inv_pred)
rmse = np.sqrt(mse)
r2 = r2_score(inv_test, inv_pred)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 15495.46
# MAPE: 136.26%
# MSE: 301327732.71
# RMSE: 17358.79
# R2: -0.05

# %% [markdown]
# # Tạo một DataFrame là 'df_pred' để lưu kết quả dự đoán trên mô hình ARIMA

# %%
df_pred = pd.DataFrame(index=index_test)
df_pred['actual'] = inv_test
df_pred['arima'] = inv_pred
df_pred['error'] = inv_test - inv_pred
df_pred
# Out:
#                            actual         arima         error
# formatted_date
# 1546300800000000000   3943.409424  27438.240234 -23494.830811
# 1546387200000000000   3836.741211  27438.240234 -23601.499023
# 1546473600000000000   3857.717529  27438.240234 -23580.522705
# 1546560000000000000   3845.194580  27438.240234 -23593.045654
# 1546646400000000000   4076.632568  27438.240234 -23361.607666
# ...                           ...           ...           ...
# 1681948800000000000  27276.910156  27438.240234   -161.330078
# 1682035200000000000  27817.500000  27438.240234    379.259766
# 1682121600000000000  27591.384766  27438.240234    153.144531
# 1682208000000000000  27525.339844  27438.240234     87.099609
# 1682294400000000000  27438.240234  27438.240234      0.000000
#
# [1575 rows x 3 columns]

# %% [markdown]
# ## 2. Quá trình dự đoán trên mô hình svr

# %% [markdown]
# # Tạo thêm một DataFrame để tiến hành dự đoán sai số trên mô hình svr

# %%
df_svr = df_pred.copy()
df_svr
# Out:
#                            actual         arima         error
# formatted_date
# 1546300800000000000   3943.409424  27438.240234 -23494.830811
# 1546387200000000000   3836.741211  27438.240234 -23601.499023
# 1546473600000000000   3857.717529  27438.240234 -23580.522705
# 1546560000000000000   3845.194580  27438.240234 -23593.045654
# 1546646400000000000   4076.632568  27438.240234 -23361.607666
# ...                           ...           ...           ...
# 1681948800000000000  27276.910156  27438.240234   -161.330078
# 1682035200000000000  27817.500000  27438.240234    379.259766
# 1682121600000000000  27591.384766  27438.240234    153.144531
# 1682208000000000000  27525.339844  27438.240234     87.099609
# 1682294400000000000  27438.240234  27438.240234      0.000000
#
# [1575 rows x 3 columns]

# %% [markdown]
# # Vẽ đồ thị thể hiện sai số

# %%
formatter = ticker.StrMethodFormatter('${x:,.0f}')

df_svr = df_svr.drop(columns=['actual', 'arima'])
timestamp = pd.to_datetime(df_svr.index).astype(np.int64) / 10**9
df_svr['timestamp'] = timestamp
df_svr.tail()
# Out:
#                           error     timestamp
# formatted_date
# 1681948800000000000 -161.330078  1.681949e+09
# 1682035200000000000  379.259766  1.682035e+09
# 1682121600000000000  153.144531  1.682122e+09
# 1682208000000000000   87.099609  1.682208e+09
# 1682294400000000000    0.000000  1.682294e+09

# %%
svr_x_sc = StandardScaler()
svr_y_sc = StandardScaler()

x = df_svr.iloc[:, -1].values
y = df_svr.iloc[:, 0].values

x_scaled = svr_x_sc.fit_transform(x.reshape(-1, 1))
y_scaled = svr_y_sc.fit_transform(y.reshape(-1, 1))

print(x_scaled.shape)
print(y_scaled.shape)
# Out:
# (1575, 1)
# (1575, 1)

# %%
formatter = ticker.StrMethodFormatter('${x:,.0f}')

title = 'Residual from ARIMA model'
ylabel = 'USD'
xlabel = 'Date'

ax = df_svr['error'].plot(figsize=(16, 9), title=title)
ax.autoscale(axis='x', tight=True)
ax.set(xlabel=xlabel, ylabel=ylabel)
ax.yaxis.set_major_formatter(formatter)
ax.grid(True)

# %%
def para_range(minimum, maximum, step):
    para_list = np.arange(minimum, maximum, step)
    return para_list


def print_stats(hyperparams, stats):
    if(hyperparams[0] == 'poly'):
        print(
            f'SVR(kernel={hyperparams[0]}, C={hyperparams[1]}, gamma={hyperparams[2]}, degree={hyperparams[3]}')
    else:
        print(
            f'SVR(kernel={hyperparams[0]}, C={hyperparams[1]}, gamma={hyperparams[2]}')

    print(
        f"MAE={stats[0]:.2f} | MSE={stats[1] :.2f} | RMSE={stats[2]:.2f}")

# %%
kernels = ['sigmoid', 'rbf', 'poly']
Cs = para_range(0.01, 0.2, 0.1)
gammas = para_range(0.1, 5, 0.1)
degrees = para_range(1, 6, 1)

# %%
warnings.filterwarnings('ignore')

stats_df = pd.DataFrame(
    columns=['kernel', 'C', 'gamma', 'degree', 'MAE', 'MSE', 'RMSE'])

# Sử dụng gird-seach để tìm hyperparameters phù hợp
for ker in kernels:
    # Nếu kernel == poly thì thực hiện chọn degree
    if(ker != 'poly'):
        for C in Cs:
            for gamma in gammas:
                rgs = SVR(kernel=ker, C=C, gamma=gamma, verbose=False)
                rgs.fit(x_scaled, y_scaled)
                pred = rgs.predict(x_scaled)

                # Đảo tỷ lệ thành giá trị thực
                inv_pred = svr_y_sc.inverse_transform(
                    column_or_1d(pred).reshape(-1, 1))
                inv_y = svr_y_sc.inverse_transform(
                    column_or_1d(y_scaled).reshape(-1, 1))

                # Đánh giá mô hình
                mae = mean_absolute_error(inv_y, inv_pred)
                mse = mean_squared_error(inv_y, inv_pred)
                rmse = np.sqrt(mse)

                result = {'kernel': ker, 'C': C, 'gamma': gamma,
                          'degree': 0, 'MAE': mae, 'MSE': mse, 'RMSE': rmse}

                hyperparam = [ker, C, gamma, 0]
                stats = [mae, mse, rmse]
                stats_df = stats_df.append(result, ignore_index=True)
                print_stats(hyperparam, stats)
    else:
        for C in Cs:
            for gamma in gammas:
                for deg in degrees:
                    rgs = SVR(kernel=ker, C=C, gamma=gamma,
                              degree=deg, verbose=False)
                    rgs.fit(x_scaled, y_scaled)
                    pred = rgs.predict(x_scaled)

                    # Đảo tỷ lệ thành giá trị thực
                    inv_pred = svr_y_sc.inverse_transform(
                        column_or_1d(pred).reshape(-1, 1))
                    inv_y = svr_y_sc.inverse_transform(
                        column_or_1d(y_scaled).reshape(-1, 1))

                    # Đánh giá mô hình
                    mae = mean_absolute_error(inv_y, inv_pred)
                    mse = mean_squared_error(inv_y, inv_pred)
                    rmse = np.sqrt(mse)

                    hyperparam = [ker, C, gamma, deg]
                    stats = [mae, mse, rmse]
                    result = {'kernel': ker, 'C': C, 'gamma': gamma, 'degree': deg,
                              'MAE': mae, 'MSE': mse, 'RMSE': rmse}

                    stats_df = stats_df.append(result, ignore_index=True)

                    print_stats(hyperparam, stats)
# Out:
# SVR(kernel=sigmoid, C=0.01, gamma=0.1
# MAE=10657.67 | MSE=268926830.11 | RMSE=16398.99
# SVR(kernel=sigmoid, C=0.01, gamma=0.2
# MAE=10581.43 | MSE=262477636.83 | RMSE=16201.16
# SVR(kernel=sigmoid, C=0.01, gamma=0.30000000000000004
# MAE=10672.15 | MSE=259480675.80 | RMSE=16108.40
# SVR(kernel=sigmoid, C=0.01, gamma=0.4
# MAE=10984.34 | MSE=271441996.77 | RMSE=16475.50
# SVR(kernel=sigmoid, C=0.01, gamma=0.5
# MAE=11657.08 | MSE=291355908.31 | RMSE=17069.15
# SVR(kernel=sigmoid, C=0.01, gamma=0.6
# MAE=12655.49 | MSE=314268191.54 | RMSE=17727.61
# SVR(kernel=sigmoid, C=0.01, gamma=0.7000000000000001
# MAE=13668.38 | MSE=336433505.26 | RMSE=18342.12
# SVR(kernel=sigmoid, C=0.01, gamma=0.8
# MAE=14801.53 | MSE=368565227.80 | RMSE=19198.05
# SVR(kernel=sigmoid, C=0.01, gamma=0.9
# MAE=15839.54 | MSE=402158030.72 | RMSE=20053.88
# SVR(kernel=sigmoid, C=0.01, gamma=1.0
# MAE=16706.02 | MSE=436573853.80 | RMSE=20894.35
# SVR(kernel=sigmoid, C=0.01, gamma=1.1
# MAE=17483.93 | MSE=471174273.42 | RMSE=21706.55
# SVR(kernel=sigmoid, C=0.01, gamma=1.2000000000000002
# MAE=18189.69 | MSE=505677721.29 | RMSE=22487.28
# SVR(kernel=sigmoid, C=0.01, gamma=1.3000000000000003
# MAE=18809.58 | MSE=537341331.71 | RMSE=23180.62
# SVR(kernel=sigmoid, C=0.01, gamma=1.4000000000000001
# MAE=19287.22 | MSE=543848627.03 | RMSE=23320.56
# SVR(kernel=sigmoid, C=0.01, gamma=1.5000000000000002
# MAE=19715.92 | MSE=553835891.00 | RMSE=23533.72
# SVR(kernel=sigmoid, C=0.01, gamma=1.6
# MAE=20028.53 | MSE=564867326.39 | RMSE=23766.94
# SVR(kernel=sigmoid, C=0.01, gamma=1.7000000000000002
# MAE=20324.67 | MSE=584984257.78 | RMSE=24186.45
# SVR(kernel=sigmoid, C=0.01, gamma=1.8000000000000003
# MAE=20530.35 | MSE=599929067.41 | RMSE=24493.45
# SVR(kernel=sigmoid, C=0.01, gamma=1.9000000000000001
# MAE=20696.10 | MSE=613365642.59 | RMSE=24766.22
# SVR(kernel=sigmoid, C=0.01, gamma=2.0
# MAE=20833.57 | MSE=627104329.31 | RMSE=25042.05
# SVR(kernel=sigmoid, C=0.01, gamma=2.1
# MAE=20937.23 | MSE=637879914.25 | RMSE=25256.28
# SVR(kernel=sigmoid, C=0.01, gamma=2.2
# MAE=21030.85 | MSE=648893477.89 | RMSE=25473.39
# SVR(kernel=sigmoid, C=0.01, gamma=2.3000000000000003
# MAE=21057.11 | MSE=653822887.45 | RMSE=25569.96
# SVR(kernel=sigmoid, C=0.01, gamma=2.4000000000000004
# MAE=21073.58 | MSE=659635878.61 | RMSE=25683.38
# SVR(kernel=sigmoid, C=0.01, gamma=2.5000000000000004
# MAE=21099.29 | MSE=664896235.00 | RMSE=25785.58
# SVR(kernel=sigmoid, C=0.01, gamma=2.6
# MAE=21137.16 | MSE=672244557.19 | RMSE=25927.68
# SVR(kernel=sigmoid, C=0.01, gamma=2.7
# MAE=21160.21 | MSE=678992803.61 | RMSE=26057.49
# SVR(kernel=sigmoid, C=0.01, gamma=2.8000000000000003
# MAE=21192.12 | MSE=686230269.18 | RMSE=26196.00
# SVR(kernel=sigmoid, C=0.01, gamma=2.9000000000000004
# MAE=21162.26 | MSE=689709805.22 | RMSE=26262.33
# SVR(kernel=sigmoid, C=0.01, gamma=3.0000000000000004
# MAE=21222.90 | MSE=697999353.12 | RMSE=26419.68
# SVR(kernel=sigmoid, C=0.01, gamma=3.1
# MAE=21186.39 | MSE=700919536.21 | RMSE=26474.89
# SVR(kernel=sigmoid, C=0.01, gamma=3.2
# MAE=21165.17 | MSE=704564613.81 | RMSE=26543.64
# SVR(kernel=sigmoid, C=0.01, gamma=3.3000000000000003
# MAE=21115.75 | MSE=704365735.06 | RMSE=26539.89
# SVR(kernel=sigmoid, C=0.01, gamma=3.4000000000000004
# MAE=21034.05 | MSE=703530775.51 | RMSE=26524.15
# SVR(kernel=sigmoid, C=0.01, gamma=3.5000000000000004
# MAE=20982.24 | MSE=704852476.18 | RMSE=26549.06
# SVR(kernel=sigmoid, C=0.01, gamma=3.6
# MAE=20916.31 | MSE=704508231.02 | RMSE=26542.57
# SVR(kernel=sigmoid, C=0.01, gamma=3.7
# MAE=20819.98 | MSE=702362682.88 | RMSE=26502.13
# SVR(kernel=sigmoid, C=0.01, gamma=3.8000000000000003
# MAE=20716.30 | MSE=696938445.79 | RMSE=26399.59
# SVR(kernel=sigmoid, C=0.01, gamma=3.9000000000000004
# MAE=20631.40 | MSE=696080964.55 | RMSE=26383.35
# SVR(kernel=sigmoid, C=0.01, gamma=4.0
# MAE=20536.70 | MSE=692902456.95 | RMSE=26323.04
# SVR(kernel=sigmoid, C=0.01, gamma=4.1
# MAE=20444.48 | MSE=690166257.06 | RMSE=26271.02
# SVR(kernel=sigmoid, C=0.01, gamma=4.2
# MAE=20340.53 | MSE=687997932.66 | RMSE=26229.71
# SVR(kernel=sigmoid, C=0.01, gamma=4.3
# MAE=20229.10 | MSE=683212901.74 | RMSE=26138.34
# SVR(kernel=sigmoid, C=0.01, gamma=4.3999999999999995
# MAE=20132.18 | MSE=679428340.18 | RMSE=26065.85
# SVR(kernel=sigmoid, C=0.01, gamma=4.5
# MAE=20019.31 | MSE=673532910.98 | RMSE=25952.51
# SVR(kernel=sigmoid, C=0.01, gamma=4.6
# MAE=19925.46 | MSE=671201360.51 | RMSE=25907.55
# SVR(kernel=sigmoid, C=0.01, gamma=4.7
# MAE=19841.72 | MSE=669077065.84 | RMSE=25866.52
# SVR(kernel=sigmoid, C=0.01, gamma=4.8
# MAE=19740.26 | MSE=664902057.97 | RMSE=25785.69
# SVR(kernel=sigmoid, C=0.01, gamma=4.9
# MAE=19628.99 | MSE=660879879.46 | RMSE=25707.58
# SVR(kernel=sigmoid, C=0.11, gamma=0.1
# MAE=10631.23 | MSE=251986728.17 | RMSE=15874.09
# SVR(kernel=sigmoid, C=0.11, gamma=0.2
# MAE=12227.95 | MSE=300025456.98 | RMSE=17321.24
# SVR(kernel=sigmoid, C=0.11, gamma=0.30000000000000004
# MAE=17817.35 | MSE=453823343.63 | RMSE=21303.13
# SVR(kernel=sigmoid, C=0.11, gamma=0.4
# MAE=26386.79 | MSE=893104856.42 | RMSE=29884.86
# SVR(kernel=sigmoid, C=0.11, gamma=0.5
# MAE=37459.72 | MSE=1785842748.50 | RMSE=42259.23
# SVR(kernel=sigmoid, C=0.11, gamma=0.6
# MAE=50111.23 | MSE=3215366871.30 | RMSE=56704.21
# SVR(kernel=sigmoid, C=0.11, gamma=0.7000000000000001
# MAE=63421.87 | MSE=5127477921.00 | RMSE=71606.41
# SVR(kernel=sigmoid, C=0.11, gamma=0.8
# MAE=76343.62 | MSE=7376749775.71 | RMSE=85888.01
# SVR(kernel=sigmoid, C=0.11, gamma=0.9
# MAE=88586.93 | MSE=9879129538.76 | RMSE=99393.81
# SVR(kernel=sigmoid, C=0.11, gamma=1.0
# MAE=99897.98 | MSE=12507253084.13 | RMSE=111835.83
# SVR(kernel=sigmoid, C=0.11, gamma=1.1
# MAE=110092.86 | MSE=15155051292.19 | RMSE=123105.85
# SVR(kernel=sigmoid, C=0.11, gamma=1.2000000000000002
# MAE=119294.07 | MSE=17798260113.04 | RMSE=133410.12
# SVR(kernel=sigmoid, C=0.11, gamma=1.3000000000000003
# MAE=127480.63 | MSE=20361206806.75 | RMSE=142692.70
# SVR(kernel=sigmoid, C=0.11, gamma=1.4000000000000001
# MAE=134661.97 | MSE=22812844122.56 | RMSE=151039.21
# SVR(kernel=sigmoid, C=0.11, gamma=1.5000000000000002
# MAE=140949.94 | MSE=25164901596.36 | RMSE=158634.49
# SVR(kernel=sigmoid, C=0.11, gamma=1.6
# MAE=146389.51 | MSE=27342217041.44 | RMSE=165354.82
# SVR(kernel=sigmoid, C=0.11, gamma=1.7000000000000002
# MAE=151121.48 | MSE=29339213729.41 | RMSE=171286.93
# SVR(kernel=sigmoid, C=0.11, gamma=1.8000000000000003
# MAE=155155.45 | MSE=31138593014.42 | RMSE=176461.31
# SVR(kernel=sigmoid, C=0.11, gamma=1.9000000000000001
# MAE=158584.81 | MSE=32835272372.06 | RMSE=181205.06
# SVR(kernel=sigmoid, C=0.11, gamma=2.0
# MAE=161453.92 | MSE=34406120116.95 | RMSE=185488.87
# SVR(kernel=sigmoid, C=0.11, gamma=2.1
# MAE=163881.13 | MSE=35844444035.39 | RMSE=189326.29
# SVR(kernel=sigmoid, C=0.11, gamma=2.2
# MAE=165882.09 | MSE=37142064725.00 | RMSE=192722.77
# SVR(kernel=sigmoid, C=0.11, gamma=2.3000000000000003
# MAE=167545.84 | MSE=38397974331.89 | RMSE=195954.01
# SVR(kernel=sigmoid, C=0.11, gamma=2.4000000000000004
# MAE=168867.10 | MSE=39467153180.68 | RMSE=198663.42
# SVR(kernel=sigmoid, C=0.11, gamma=2.5000000000000004
# MAE=169940.62 | MSE=40493639947.11 | RMSE=201230.32
# SVR(kernel=sigmoid, C=0.11, gamma=2.6
# MAE=170768.62 | MSE=41406586998.94 | RMSE=203486.09
# SVR(kernel=sigmoid, C=0.11, gamma=2.7
# MAE=171361.69 | MSE=42257846095.37 | RMSE=205567.13
# SVR(kernel=sigmoid, C=0.11, gamma=2.8000000000000003
# MAE=171791.66 | MSE=43014275555.83 | RMSE=207398.83
# SVR(kernel=sigmoid, C=0.11, gamma=2.9000000000000004
# MAE=172026.03 | MSE=43630458333.67 | RMSE=208879.05
# SVR(kernel=sigmoid, C=0.11, gamma=3.0000000000000004
# MAE=172141.27 | MSE=44251151167.15 | RMSE=210359.58
# SVR(kernel=sigmoid, C=0.11, gamma=3.1
# MAE=172103.56 | MSE=44764339204.84 | RMSE=211575.85
# SVR(kernel=sigmoid, C=0.11, gamma=3.2
# MAE=172001.71 | MSE=45270890256.90 | RMSE=212769.57
# SVR(kernel=sigmoid, C=0.11, gamma=3.3000000000000003
# MAE=171758.58 | MSE=45684545946.61 | RMSE=213739.43
# SVR(kernel=sigmoid, C=0.11, gamma=3.4000000000000004
# MAE=171440.22 | MSE=46075658355.84 | RMSE=214652.41
# SVR(kernel=sigmoid, C=0.11, gamma=3.5000000000000004
# MAE=171060.31 | MSE=46355817094.50 | RMSE=215304.01
# SVR(kernel=sigmoid, C=0.11, gamma=3.6
# MAE=170588.96 | MSE=46624832873.44 | RMSE=215927.84
# SVR(kernel=sigmoid, C=0.11, gamma=3.7
# MAE=170077.55 | MSE=46900841087.93 | RMSE=216566.02
# SVR(kernel=sigmoid, C=0.11, gamma=3.8000000000000003
# MAE=169499.44 | MSE=47069390281.62 | RMSE=216954.81
# SVR(kernel=sigmoid, C=0.11, gamma=3.9000000000000004
# MAE=168870.35 | MSE=47175889309.95 | RMSE=217200.11
# SVR(kernel=sigmoid, C=0.11, gamma=4.0
# MAE=168195.01 | MSE=47142341953.75 | RMSE=217122.87
# SVR(kernel=sigmoid, C=0.11, gamma=4.1
# MAE=167507.95 | MSE=47210189515.90 | RMSE=217279.06
# SVR(kernel=sigmoid, C=0.11, gamma=4.2
# MAE=166773.35 | MSE=47226244537.78 | RMSE=217316.00
# SVR(kernel=sigmoid, C=0.11, gamma=4.3
# MAE=166019.00 | MSE=47278590923.80 | RMSE=217436.41
# SVR(kernel=sigmoid, C=0.11, gamma=4.3999999999999995
# MAE=165259.26 | MSE=47243449277.94 | RMSE=217355.58
# SVR(kernel=sigmoid, C=0.11, gamma=4.5
# MAE=164464.49 | MSE=47214759084.69 | RMSE=217289.57
# SVR(kernel=sigmoid, C=0.11, gamma=4.6
# MAE=163656.17 | MSE=47210590438.01 | RMSE=217279.98
# SVR(kernel=sigmoid, C=0.11, gamma=4.7
# MAE=162832.74 | MSE=47164814811.60 | RMSE=217174.62
# SVR(kernel=sigmoid, C=0.11, gamma=4.8
# MAE=162002.38 | MSE=47150536597.54 | RMSE=217141.74
# SVR(kernel=sigmoid, C=0.11, gamma=4.9
# MAE=161173.22 | MSE=47028447860.13 | RMSE=216860.43
# SVR(kernel=rbf, C=0.01, gamma=0.1
# MAE=9986.79 | MSE=221638683.68 | RMSE=14887.53
# SVR(kernel=rbf, C=0.01, gamma=0.2
# MAE=9202.52 | MSE=171337878.15 | RMSE=13089.61
# SVR(kernel=rbf, C=0.01, gamma=0.30000000000000004
# MAE=8387.33 | MSE=136122033.69 | RMSE=11667.13
# SVR(kernel=rbf, C=0.01, gamma=0.4
# MAE=7732.26 | MSE=111401357.86 | RMSE=10554.68
# SVR(kernel=rbf, C=0.01, gamma=0.5
# MAE=7312.74 | MSE=99768236.30 | RMSE=9988.41
# SVR(kernel=rbf, C=0.01, gamma=0.6
# MAE=6939.76 | MSE=90814201.39 | RMSE=9529.65
# SVR(kernel=rbf, C=0.01, gamma=0.7000000000000001
# MAE=6631.23 | MSE=84008572.58 | RMSE=9165.62
# SVR(kernel=rbf, C=0.01, gamma=0.8
# MAE=6350.01 | MSE=78394294.65 | RMSE=8854.06
# SVR(kernel=rbf, C=0.01, gamma=0.9
# MAE=6093.58 | MSE=73675447.88 | RMSE=8583.44
# SVR(kernel=rbf, C=0.01, gamma=1.0
# MAE=5848.50 | MSE=69338656.76 | RMSE=8326.98
# SVR(kernel=rbf, C=0.01, gamma=1.1
# MAE=5618.30 | MSE=66321500.69 | RMSE=8143.80
# SVR(kernel=rbf, C=0.01, gamma=1.2000000000000002
# MAE=5429.37 | MSE=63782944.89 | RMSE=7986.42
# SVR(kernel=rbf, C=0.01, gamma=1.3000000000000003
# MAE=5259.24 | MSE=61264724.39 | RMSE=7827.18
# SVR(kernel=rbf, C=0.01, gamma=1.4000000000000001
# MAE=5131.41 | MSE=59557022.25 | RMSE=7717.32
# SVR(kernel=rbf, C=0.01, gamma=1.5000000000000002
# MAE=5006.11 | MSE=57693295.58 | RMSE=7595.61
# SVR(kernel=rbf, C=0.01, gamma=1.6
# MAE=4905.55 | MSE=56842442.87 | RMSE=7539.39
# SVR(kernel=rbf, C=0.01, gamma=1.7000000000000002
# MAE=4820.40 | MSE=55757603.88 | RMSE=7467.10
# SVR(kernel=rbf, C=0.01, gamma=1.8000000000000003
# MAE=4751.54 | MSE=54717603.86 | RMSE=7397.13
# SVR(kernel=rbf, C=0.01, gamma=1.9000000000000001
# MAE=4696.14 | MSE=54097760.68 | RMSE=7355.12
# SVR(kernel=rbf, C=0.01, gamma=2.0
# MAE=4641.65 | MSE=53351438.48 | RMSE=7304.21
# SVR(kernel=rbf, C=0.01, gamma=2.1
# MAE=4591.25 | MSE=52700600.73 | RMSE=7259.52
# SVR(kernel=rbf, C=0.01, gamma=2.2
# MAE=4555.96 | MSE=52124690.81 | RMSE=7219.74
# SVR(kernel=rbf, C=0.01, gamma=2.3000000000000003
# MAE=4522.42 | MSE=51496962.42 | RMSE=7176.14
# SVR(kernel=rbf, C=0.01, gamma=2.4000000000000004
# MAE=4497.00 | MSE=51107061.19 | RMSE=7148.92
# SVR(kernel=rbf, C=0.01, gamma=2.5000000000000004
# MAE=4478.24 | MSE=50860260.40 | RMSE=7131.64
# SVR(kernel=rbf, C=0.01, gamma=2.6
# MAE=4453.98 | MSE=50645577.75 | RMSE=7116.57
# SVR(kernel=rbf, C=0.01, gamma=2.7
# MAE=4431.13 | MSE=50372499.77 | RMSE=7097.36
# SVR(kernel=rbf, C=0.01, gamma=2.8000000000000003
# MAE=4407.48 | MSE=50160494.74 | RMSE=7082.41
# SVR(kernel=rbf, C=0.01, gamma=2.9000000000000004
# MAE=4386.65 | MSE=49903532.98 | RMSE=7064.24
# SVR(kernel=rbf, C=0.01, gamma=3.0000000000000004
# MAE=4370.43 | MSE=49773822.13 | RMSE=7055.06
# SVR(kernel=rbf, C=0.01, gamma=3.1
# MAE=4355.79 | MSE=49654292.06 | RMSE=7046.58
# SVR(kernel=rbf, C=0.01, gamma=3.2
# MAE=4336.23 | MSE=49439276.44 | RMSE=7031.31
# SVR(kernel=rbf, C=0.01, gamma=3.3000000000000003
# MAE=4317.78 | MSE=49283801.39 | RMSE=7020.24
# SVR(kernel=rbf, C=0.01, gamma=3.4000000000000004
# MAE=4305.48 | MSE=49149861.45 | RMSE=7010.70
# SVR(kernel=rbf, C=0.01, gamma=3.5000000000000004
# MAE=4294.42 | MSE=49165980.66 | RMSE=7011.85
# SVR(kernel=rbf, C=0.01, gamma=3.6
# MAE=4279.14 | MSE=48956923.67 | RMSE=6996.92
# SVR(kernel=rbf, C=0.01, gamma=3.7
# MAE=4267.70 | MSE=48827226.27 | RMSE=6987.65
# SVR(kernel=rbf, C=0.01, gamma=3.8000000000000003
# MAE=4253.78 | MSE=48667225.91 | RMSE=6976.19
# SVR(kernel=rbf, C=0.01, gamma=3.9000000000000004
# MAE=4242.31 | MSE=48584991.99 | RMSE=6970.29
# SVR(kernel=rbf, C=0.01, gamma=4.0
# MAE=4229.56 | MSE=48474196.98 | RMSE=6962.34
# SVR(kernel=rbf, C=0.01, gamma=4.1
# MAE=4217.54 | MSE=48284173.05 | RMSE=6948.68
# SVR(kernel=rbf, C=0.01, gamma=4.2
# MAE=4205.15 | MSE=48118905.81 | RMSE=6936.78
# SVR(kernel=rbf, C=0.01, gamma=4.3
# MAE=4199.59 | MSE=48061282.31 | RMSE=6932.62
# SVR(kernel=rbf, C=0.01, gamma=4.3999999999999995
# MAE=4184.26 | MSE=47860282.57 | RMSE=6918.11
# SVR(kernel=rbf, C=0.01, gamma=4.5
# MAE=4167.14 | MSE=47546068.69 | RMSE=6895.37
# SVR(kernel=rbf, C=0.01, gamma=4.6
# MAE=4156.43 | MSE=47424090.42 | RMSE=6886.52
# SVR(kernel=rbf, C=0.01, gamma=4.7
# MAE=4143.01 | MSE=47217610.04 | RMSE=6871.51
# SVR(kernel=rbf, C=0.01, gamma=4.8
# MAE=4129.80 | MSE=47002815.60 | RMSE=6855.86
# SVR(kernel=rbf, C=0.01, gamma=4.9
# MAE=4119.28 | MSE=46876061.74 | RMSE=6846.61
# SVR(kernel=rbf, C=0.11, gamma=0.1
# MAE=8914.55 | MSE=137365693.34 | RMSE=11720.31
# SVR(kernel=rbf, C=0.11, gamma=0.2
# MAE=7470.83 | MSE=97345849.01 | RMSE=9866.40
# SVR(kernel=rbf, C=0.11, gamma=0.30000000000000004
# MAE=6872.81 | MSE=81972338.64 | RMSE=9053.86
# SVR(kernel=rbf, C=0.11, gamma=0.4
# MAE=6324.72 | MSE=71605007.24 | RMSE=8461.97
# SVR(kernel=rbf, C=0.11, gamma=0.5
# MAE=5682.56 | MSE=62323233.30 | RMSE=7894.51
# SVR(kernel=rbf, C=0.11, gamma=0.6
# MAE=5080.57 | MSE=53146961.62 | RMSE=7290.20
# SVR(kernel=rbf, C=0.11, gamma=0.7000000000000001
# MAE=4592.38 | MSE=47249954.77 | RMSE=6873.86
# SVR(kernel=rbf, C=0.11, gamma=0.8
# MAE=4272.89 | MSE=43083595.11 | RMSE=6563.81
# SVR(kernel=rbf, C=0.11, gamma=0.9
# MAE=4116.41 | MSE=41275623.77 | RMSE=6424.61
# SVR(kernel=rbf, C=0.11, gamma=1.0
# MAE=4003.80 | MSE=40379720.80 | RMSE=6354.50
# SVR(kernel=rbf, C=0.11, gamma=1.1
# MAE=3934.18 | MSE=40104972.36 | RMSE=6332.85
# SVR(kernel=rbf, C=0.11, gamma=1.2000000000000002
# MAE=3897.98 | MSE=39790086.88 | RMSE=6307.94
# SVR(kernel=rbf, C=0.11, gamma=1.3000000000000003
# MAE=3878.36 | MSE=39574219.15 | RMSE=6290.80
# SVR(kernel=rbf, C=0.11, gamma=1.4000000000000001
# MAE=3860.36 | MSE=39284166.26 | RMSE=6267.71
# SVR(kernel=rbf, C=0.11, gamma=1.5000000000000002
# MAE=3845.71 | MSE=39141605.56 | RMSE=6256.33
# SVR(kernel=rbf, C=0.11, gamma=1.6
# MAE=3832.26 | MSE=38964737.29 | RMSE=6242.17
# SVR(kernel=rbf, C=0.11, gamma=1.7000000000000002
# MAE=3816.20 | MSE=38798265.71 | RMSE=6228.83
# SVR(kernel=rbf, C=0.11, gamma=1.8000000000000003
# MAE=3812.68 | MSE=38460870.74 | RMSE=6201.68
# SVR(kernel=rbf, C=0.11, gamma=1.9000000000000001
# MAE=3803.42 | MSE=38203535.73 | RMSE=6180.90
# SVR(kernel=rbf, C=0.11, gamma=2.0
# MAE=3797.80 | MSE=37874383.85 | RMSE=6154.22
# SVR(kernel=rbf, C=0.11, gamma=2.1
# MAE=3790.93 | MSE=37508789.96 | RMSE=6124.44
# SVR(kernel=rbf, C=0.11, gamma=2.2
# MAE=3779.83 | MSE=37217277.81 | RMSE=6100.60
# SVR(kernel=rbf, C=0.11, gamma=2.3000000000000003
# MAE=3769.97 | MSE=36917789.48 | RMSE=6076.00
# SVR(kernel=rbf, C=0.11, gamma=2.4000000000000004
# MAE=3758.23 | MSE=36435698.11 | RMSE=6036.20
# SVR(kernel=rbf, C=0.11, gamma=2.5000000000000004
# MAE=3744.15 | MSE=35807146.24 | RMSE=5983.91
# SVR(kernel=rbf, C=0.11, gamma=2.6
# MAE=3728.27 | MSE=35240166.39 | RMSE=5936.34
# SVR(kernel=rbf, C=0.11, gamma=2.7
# MAE=3712.32 | MSE=34905630.09 | RMSE=5908.10
# SVR(kernel=rbf, C=0.11, gamma=2.8000000000000003
# MAE=3697.98 | MSE=34554351.90 | RMSE=5878.29
# SVR(kernel=rbf, C=0.11, gamma=2.9000000000000004
# MAE=3684.53 | MSE=34233399.10 | RMSE=5850.93
# SVR(kernel=rbf, C=0.11, gamma=3.0000000000000004
# MAE=3665.58 | MSE=33950973.04 | RMSE=5826.75
# SVR(kernel=rbf, C=0.11, gamma=3.1
# MAE=3647.49 | MSE=33311980.25 | RMSE=5771.65
# SVR(kernel=rbf, C=0.11, gamma=3.2
# MAE=3626.52 | MSE=32966541.50 | RMSE=5741.65
# SVR(kernel=rbf, C=0.11, gamma=3.3000000000000003
# MAE=3607.17 | MSE=32570555.16 | RMSE=5707.06
# SVR(kernel=rbf, C=0.11, gamma=3.4000000000000004
# MAE=3591.74 | MSE=32297126.31 | RMSE=5683.06
# SVR(kernel=rbf, C=0.11, gamma=3.5000000000000004
# MAE=3572.25 | MSE=31892023.19 | RMSE=5647.30
# SVR(kernel=rbf, C=0.11, gamma=3.6
# MAE=3557.47 | MSE=31597601.72 | RMSE=5621.17
# SVR(kernel=rbf, C=0.11, gamma=3.7
# MAE=3541.92 | MSE=31239895.03 | RMSE=5589.27
# SVR(kernel=rbf, C=0.11, gamma=3.8000000000000003
# MAE=3522.45 | MSE=30773374.81 | RMSE=5547.38
# SVR(kernel=rbf, C=0.11, gamma=3.9000000000000004
# MAE=3503.82 | MSE=30389804.97 | RMSE=5512.69
# SVR(kernel=rbf, C=0.11, gamma=4.0
# MAE=3491.88 | MSE=29986859.32 | RMSE=5476.03
# SVR(kernel=rbf, C=0.11, gamma=4.1
# MAE=3467.17 | MSE=29139406.40 | RMSE=5398.09
# SVR(kernel=rbf, C=0.11, gamma=4.2
# MAE=3447.57 | MSE=28749731.07 | RMSE=5361.88
# SVR(kernel=rbf, C=0.11, gamma=4.3
# MAE=3427.37 | MSE=28438042.87 | RMSE=5332.73
# SVR(kernel=rbf, C=0.11, gamma=4.3999999999999995
# MAE=3411.71 | MSE=28069654.36 | RMSE=5298.08
# SVR(kernel=rbf, C=0.11, gamma=4.5
# MAE=3392.49 | MSE=27644914.67 | RMSE=5257.84
# SVR(kernel=rbf, C=0.11, gamma=4.6
# MAE=3373.93 | MSE=27426769.34 | RMSE=5237.06
# SVR(kernel=rbf, C=0.11, gamma=4.7
# MAE=3358.92 | MSE=27207324.02 | RMSE=5216.06
# SVR(kernel=rbf, C=0.11, gamma=4.8
# MAE=3337.49 | MSE=26905587.98 | RMSE=5187.06
# SVR(kernel=rbf, C=0.11, gamma=4.9
# MAE=3321.33 | MSE=26677070.02 | RMSE=5164.98
# SVR(kernel=poly, C=0.01, gamma=0.1, degree=1
# MAE=10661.04 | MSE=269203920.25 | RMSE=16407.43
# SVR(kernel=poly, C=0.01, gamma=0.1, degree=2
# MAE=13813.67 | MSE=300512949.69 | RMSE=17335.31
# SVR(kernel=poly, C=0.01, gamma=0.1, degree=3
# MAE=13661.22 | MSE=312205973.37 | RMSE=17669.35
# SVR(kernel=poly, C=0.01, gamma=0.1, degree=4
# MAE=13915.41 | MSE=311012924.67 | RMSE=17635.56
# SVR(kernel=poly, C=0.01, gamma=0.1, degree=5
# MAE=13909.29 | MSE=311442967.53 | RMSE=17647.75
# SVR(kernel=poly, C=0.01, gamma=0.2, degree=1
# MAE=10566.86 | MSE=261598654.06 | RMSE=16174.01
# SVR(kernel=poly, C=0.01, gamma=0.2, degree=2
# MAE=13596.76 | MSE=281525221.79 | RMSE=16778.71
# SVR(kernel=poly, C=0.01, gamma=0.2, degree=3
# MAE=12352.73 | MSE=322635061.25 | RMSE=17962.05
# SVR(kernel=poly, C=0.01, gamma=0.2, degree=4
# MAE=13851.60 | MSE=304102001.05 | RMSE=17438.52
# SVR(kernel=poly, C=0.01, gamma=0.2, degree=5
# MAE=13591.37 | MSE=312302386.76 | RMSE=17672.08
# SVR(kernel=poly, C=0.01, gamma=0.30000000000000004, degree=1
# MAE=10531.08 | MSE=252880803.88 | RMSE=15902.23
# SVR(kernel=poly, C=0.01, gamma=0.30000000000000004, degree=2
# MAE=13308.15 | MSE=258147779.22 | RMSE=16066.98
# SVR(kernel=poly, C=0.01, gamma=0.30000000000000004, degree=3
# MAE=11896.32 | MSE=313786824.42 | RMSE=17714.03
# SVR(kernel=poly, C=0.01, gamma=0.30000000000000004, degree=4
# MAE=13663.65 | MSE=286753105.16 | RMSE=16933.79
# SVR(kernel=poly, C=0.01, gamma=0.30000000000000004, degree=5
# MAE=12512.77 | MSE=326757927.24 | RMSE=18076.45
# SVR(kernel=poly, C=0.01, gamma=0.4, degree=1
# MAE=10524.88 | MSE=251546832.59 | RMSE=15860.23
# SVR(kernel=poly, C=0.01, gamma=0.4, degree=2
# MAE=13073.54 | MSE=239386815.67 | RMSE=15472.13
# SVR(kernel=poly, C=0.01, gamma=0.4, degree=3
# MAE=11838.69 | MSE=312832354.80 | RMSE=17687.07
# SVR(kernel=poly, C=0.01, gamma=0.4, degree=4
# MAE=13402.02 | MSE=265562121.93 | RMSE=16296.08
# SVR(kernel=poly, C=0.01, gamma=0.4, degree=5
# MAE=12342.42 | MSE=328909496.08 | RMSE=18135.86
# SVR(kernel=poly, C=0.01, gamma=0.5, degree=1
# MAE=10523.25 | MSE=250118005.34 | RMSE=15815.12
# SVR(kernel=poly, C=0.01, gamma=0.5, degree=2
# MAE=12878.35 | MSE=228369214.87 | RMSE=15111.89
# SVR(kernel=poly, C=0.01, gamma=0.5, degree=3
# MAE=11823.24 | MSE=312439368.54 | RMSE=17675.95
# SVR(kernel=poly, C=0.01, gamma=0.5, degree=4
# MAE=13252.44 | MSE=252840807.81 | RMSE=15900.97
# SVR(kernel=poly, C=0.01, gamma=0.5, degree=5
# MAE=12327.00 | MSE=325773054.39 | RMSE=18049.18
# SVR(kernel=poly, C=0.01, gamma=0.6, degree=1
# MAE=10519.99 | MSE=249540106.87 | RMSE=15796.84
# SVR(kernel=poly, C=0.01, gamma=0.6, degree=2
# MAE=12771.87 | MSE=225636774.68 | RMSE=15021.21
# SVR(kernel=poly, C=0.01, gamma=0.6, degree=3
# MAE=11819.59 | MSE=312440924.21 | RMSE=17676.00
# SVR(kernel=poly, C=0.01, gamma=0.6, degree=4
# MAE=13227.55 | MSE=251079714.69 | RMSE=15845.50
# SVR(kernel=poly, C=0.01, gamma=0.6, degree=5
# MAE=12327.88 | MSE=324911744.06 | RMSE=18025.31
# SVR(kernel=poly, C=0.01, gamma=0.7000000000000001, degree=1
# MAE=10520.46 | MSE=249082750.54 | RMSE=15782.36
# SVR(kernel=poly, C=0.01, gamma=0.7000000000000001, degree=2
# MAE=12716.02 | MSE=225156889.63 | RMSE=15005.23
# SVR(kernel=poly, C=0.01, gamma=0.7000000000000001, degree=3
# MAE=11817.17 | MSE=312401058.64 | RMSE=17674.87
# SVR(kernel=poly, C=0.01, gamma=0.7000000000000001, degree=4
# MAE=13218.59 | MSE=249771878.26 | RMSE=15804.17
# SVR(kernel=poly, C=0.01, gamma=0.7000000000000001, degree=5
# MAE=12329.25 | MSE=324477404.75 | RMSE=18013.26
# SVR(kernel=poly, C=0.01, gamma=0.8, degree=1
# MAE=10520.40 | MSE=247938875.75 | RMSE=15746.07
# SVR(kernel=poly, C=0.01, gamma=0.8, degree=2
# MAE=12691.22 | MSE=225326236.06 | RMSE=15010.87
# SVR(kernel=poly, C=0.01, gamma=0.8, degree=3
# MAE=11815.14 | MSE=312532782.87 | RMSE=17678.60
# SVR(kernel=poly, C=0.01, gamma=0.8, degree=4
# MAE=13216.98 | MSE=249429176.93 | RMSE=15793.33
# SVR(kernel=poly, C=0.01, gamma=0.8, degree=5
# MAE=12328.78 | MSE=324791674.58 | RMSE=18021.98
# SVR(kernel=poly, C=0.01, gamma=0.9, degree=1
# MAE=10519.26 | MSE=247764195.99 | RMSE=15740.53
# SVR(kernel=poly, C=0.01, gamma=0.9, degree=2
# MAE=12678.77 | MSE=225476291.58 | RMSE=15015.87
# SVR(kernel=poly, C=0.01, gamma=0.9, degree=3
# MAE=11814.81 | MSE=312522882.03 | RMSE=17678.32
# SVR(kernel=poly, C=0.01, gamma=0.9, degree=4
# MAE=13216.98 | MSE=249404869.16 | RMSE=15792.56
# SVR(kernel=poly, C=0.01, gamma=0.9, degree=5
# MAE=12328.77 | MSE=324787344.32 | RMSE=18021.86
# SVR(kernel=poly, C=0.01, gamma=1.0, degree=1
# MAE=10519.31 | MSE=247558676.87 | RMSE=15734.00
# SVR(kernel=poly, C=0.01, gamma=1.0, degree=2
# MAE=12663.03 | MSE=225847094.60 | RMSE=15028.21
# SVR(kernel=poly, C=0.01, gamma=1.0, degree=3
# MAE=11814.71 | MSE=312463609.58 | RMSE=17676.64
# SVR(kernel=poly, C=0.01, gamma=1.0, degree=4
# MAE=13216.25 | MSE=249125265.74 | RMSE=15783.70
# SVR(kernel=poly, C=0.01, gamma=1.0, degree=5
# MAE=12328.78 | MSE=324789184.77 | RMSE=18021.91
# SVR(kernel=poly, C=0.01, gamma=1.1, degree=1
# MAE=10520.54 | MSE=247174584.48 | RMSE=15721.79
# SVR(kernel=poly, C=0.01, gamma=1.1, degree=2
# MAE=12657.33 | MSE=226062899.13 | RMSE=15035.39
# SVR(kernel=poly, C=0.01, gamma=1.1, degree=3
# MAE=11814.46 | MSE=312500849.14 | RMSE=17677.69
# SVR(kernel=poly, C=0.01, gamma=1.1, degree=4
# MAE=13215.88 | MSE=248987871.55 | RMSE=15779.35
# SVR(kernel=poly, C=0.01, gamma=1.1, degree=5
# MAE=12329.99 | MSE=324436939.86 | RMSE=18012.13
# SVR(kernel=poly, C=0.01, gamma=1.2000000000000002, degree=1
# MAE=10520.58 | MSE=246787465.94 | RMSE=15709.47
# SVR(kernel=poly, C=0.01, gamma=1.2000000000000002, degree=2
# MAE=12652.46 | MSE=226307722.50 | RMSE=15043.53
# SVR(kernel=poly, C=0.01, gamma=1.2000000000000002, degree=3
# MAE=11814.74 | MSE=312411276.36 | RMSE=17675.16
# SVR(kernel=poly, C=0.01, gamma=1.2000000000000002, degree=4
# MAE=13215.77 | MSE=248878654.79 | RMSE=15775.89
# SVR(kernel=poly, C=0.01, gamma=1.2000000000000002, degree=5
# MAE=12329.99 | MSE=324436913.81 | RMSE=18012.13
# SVR(kernel=poly, C=0.01, gamma=1.3000000000000003, degree=1
# MAE=10520.10 | MSE=246690368.24 | RMSE=15706.38
# SVR(kernel=poly, C=0.01, gamma=1.3000000000000003, degree=2
# MAE=12649.90 | MSE=226509069.90 | RMSE=15050.22
# SVR(kernel=poly, C=0.01, gamma=1.3000000000000003, degree=3
# MAE=11814.53 | MSE=312522069.72 | RMSE=17678.29
# SVR(kernel=poly, C=0.01, gamma=1.3000000000000003, degree=4
# MAE=13215.77 | MSE=248878647.19 | RMSE=15775.89
# SVR(kernel=poly, C=0.01, gamma=1.3000000000000003, degree=5
# MAE=12330.32 | MSE=324375383.61 | RMSE=18010.42
# SVR(kernel=poly, C=0.01, gamma=1.4000000000000001, degree=1
# MAE=10520.50 | MSE=246565036.28 | RMSE=15702.39
# SVR(kernel=poly, C=0.01, gamma=1.4000000000000001, degree=2
# MAE=12648.32 | MSE=226652852.30 | RMSE=15054.99
# SVR(kernel=poly, C=0.01, gamma=1.4000000000000001, degree=3
# MAE=11814.64 | MSE=312190804.35 | RMSE=17668.92
# SVR(kernel=poly, C=0.01, gamma=1.4000000000000001, degree=4
# MAE=13215.77 | MSE=248878656.49 | RMSE=15775.89
# SVR(kernel=poly, C=0.01, gamma=1.4000000000000001, degree=5
# MAE=12330.20 | MSE=324398331.86 | RMSE=18011.06
# SVR(kernel=poly, C=0.01, gamma=1.5000000000000002, degree=1
# MAE=10520.50 | MSE=246334235.71 | RMSE=15695.04
# SVR(kernel=poly, C=0.01, gamma=1.5000000000000002, degree=2
# MAE=12646.85 | MSE=226794418.58 | RMSE=15059.70
# SVR(kernel=poly, C=0.01, gamma=1.5000000000000002, degree=3
# MAE=11814.91 | MSE=312214770.45 | RMSE=17669.60
# SVR(kernel=poly, C=0.01, gamma=1.5000000000000002, degree=4
# MAE=13216.52 | MSE=248939236.25 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=1.5000000000000002, degree=5
# MAE=12330.39 | MSE=324362561.52 | RMSE=18010.07
# SVR(kernel=poly, C=0.01, gamma=1.6, degree=1
# MAE=10520.30 | MSE=246311135.20 | RMSE=15694.30
# SVR(kernel=poly, C=0.01, gamma=1.6, degree=2
# MAE=12646.01 | MSE=226875995.46 | RMSE=15062.40
# SVR(kernel=poly, C=0.01, gamma=1.6, degree=3
# MAE=11814.64 | MSE=312190831.09 | RMSE=17668.92
# SVR(kernel=poly, C=0.01, gamma=1.6, degree=4
# MAE=13216.52 | MSE=248939237.67 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=1.6, degree=5
# MAE=12329.98 | MSE=324437036.74 | RMSE=18012.14
# SVR(kernel=poly, C=0.01, gamma=1.7000000000000002, degree=1
# MAE=10519.95 | MSE=246283015.40 | RMSE=15693.41
# SVR(kernel=poly, C=0.01, gamma=1.7000000000000002, degree=2
# MAE=12645.19 | MSE=226963817.51 | RMSE=15065.32
# SVR(kernel=poly, C=0.01, gamma=1.7000000000000002, degree=3
# MAE=11814.50 | MSE=312233026.75 | RMSE=17670.12
# SVR(kernel=poly, C=0.01, gamma=1.7000000000000002, degree=4
# MAE=13216.52 | MSE=248939244.98 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=1.7000000000000002, degree=5
# MAE=12329.99 | MSE=324437018.15 | RMSE=18012.14
# SVR(kernel=poly, C=0.01, gamma=1.8000000000000003, degree=1
# MAE=10519.73 | MSE=246353727.76 | RMSE=15695.66
# SVR(kernel=poly, C=0.01, gamma=1.8000000000000003, degree=2
# MAE=12644.93 | MSE=226996150.18 | RMSE=15066.39
# SVR(kernel=poly, C=0.01, gamma=1.8000000000000003, degree=3
# MAE=11814.17 | MSE=312272810.37 | RMSE=17671.24
# SVR(kernel=poly, C=0.01, gamma=1.8000000000000003, degree=4
# MAE=13216.52 | MSE=248939240.66 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=1.8000000000000003, degree=5
# MAE=12329.98 | MSE=324436653.69 | RMSE=18012.13
# SVR(kernel=poly, C=0.01, gamma=1.9000000000000001, degree=1
# MAE=10520.29 | MSE=246240805.01 | RMSE=15692.06
# SVR(kernel=poly, C=0.01, gamma=1.9000000000000001, degree=2
# MAE=12644.78 | MSE=227015893.44 | RMSE=15067.05
# SVR(kernel=poly, C=0.01, gamma=1.9000000000000001, degree=3
# MAE=11814.30 | MSE=312283350.24 | RMSE=17671.54
# SVR(kernel=poly, C=0.01, gamma=1.9000000000000001, degree=4
# MAE=13216.52 | MSE=248939268.77 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=1.9000000000000001, degree=5
# MAE=12329.98 | MSE=324437730.69 | RMSE=18012.16
# SVR(kernel=poly, C=0.01, gamma=2.0, degree=1
# MAE=10520.14 | MSE=246265513.96 | RMSE=15692.85
# SVR(kernel=poly, C=0.01, gamma=2.0, degree=2
# MAE=12644.24 | MSE=227095900.25 | RMSE=15069.70
# SVR(kernel=poly, C=0.01, gamma=2.0, degree=3
# MAE=11814.08 | MSE=312332844.02 | RMSE=17672.94
# SVR(kernel=poly, C=0.01, gamma=2.0, degree=4
# MAE=13216.50 | MSE=248931112.15 | RMSE=15777.55
# SVR(kernel=poly, C=0.01, gamma=2.0, degree=5
# MAE=12329.99 | MSE=324434867.43 | RMSE=18012.08
# SVR(kernel=poly, C=0.01, gamma=2.1, degree=1
# MAE=10520.34 | MSE=246022617.39 | RMSE=15685.11
# SVR(kernel=poly, C=0.01, gamma=2.1, degree=2
# MAE=12643.75 | MSE=227184636.38 | RMSE=15072.65
# SVR(kernel=poly, C=0.01, gamma=2.1, degree=3
# MAE=11814.06 | MSE=312304912.15 | RMSE=17672.15
# SVR(kernel=poly, C=0.01, gamma=2.1, degree=4
# MAE=13216.50 | MSE=248931096.48 | RMSE=15777.55
# SVR(kernel=poly, C=0.01, gamma=2.1, degree=5
# MAE=12329.99 | MSE=324435816.15 | RMSE=18012.10
# SVR(kernel=poly, C=0.01, gamma=2.2, degree=1
# MAE=10519.82 | MSE=245863271.23 | RMSE=15680.03
# SVR(kernel=poly, C=0.01, gamma=2.2, degree=2
# MAE=12643.75 | MSE=227184714.27 | RMSE=15072.65
# SVR(kernel=poly, C=0.01, gamma=2.2, degree=3
# MAE=11814.39 | MSE=312257080.13 | RMSE=17670.80
# SVR(kernel=poly, C=0.01, gamma=2.2, degree=4
# MAE=13216.52 | MSE=248939262.18 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=2.2, degree=5
# MAE=12330.13 | MSE=324411912.25 | RMSE=18011.44
# SVR(kernel=poly, C=0.01, gamma=2.3000000000000003, degree=1
# MAE=10520.37 | MSE=245878806.86 | RMSE=15680.52
# SVR(kernel=poly, C=0.01, gamma=2.3000000000000003, degree=2
# MAE=12643.73 | MSE=227187919.62 | RMSE=15072.75
# SVR(kernel=poly, C=0.01, gamma=2.3000000000000003, degree=3
# MAE=11814.39 | MSE=312257716.60 | RMSE=17670.82
# SVR(kernel=poly, C=0.01, gamma=2.3000000000000003, degree=4
# MAE=13216.52 | MSE=248939186.13 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=2.3000000000000003, degree=5
# MAE=12329.98 | MSE=324435933.27 | RMSE=18012.11
# SVR(kernel=poly, C=0.01, gamma=2.4000000000000004, degree=1
# MAE=10520.37 | MSE=245878808.50 | RMSE=15680.52
# SVR(kernel=poly, C=0.01, gamma=2.4000000000000004, degree=2
# MAE=12643.28 | MSE=227289023.70 | RMSE=15076.11
# SVR(kernel=poly, C=0.01, gamma=2.4000000000000004, degree=3
# MAE=11814.10 | MSE=312303738.12 | RMSE=17672.12
# SVR(kernel=poly, C=0.01, gamma=2.4000000000000004, degree=4
# MAE=13216.49 | MSE=248932794.51 | RMSE=15777.60
# SVR(kernel=poly, C=0.01, gamma=2.4000000000000004, degree=5
# MAE=12329.99 | MSE=324436333.18 | RMSE=18012.12
# SVR(kernel=poly, C=0.01, gamma=2.5000000000000004, degree=1
# MAE=10519.95 | MSE=245727032.67 | RMSE=15675.68
# SVR(kernel=poly, C=0.01, gamma=2.5000000000000004, degree=2
# MAE=12643.28 | MSE=227289093.58 | RMSE=15076.11
# SVR(kernel=poly, C=0.01, gamma=2.5000000000000004, degree=3
# MAE=11814.35 | MSE=312298654.81 | RMSE=17671.97
# SVR(kernel=poly, C=0.01, gamma=2.5000000000000004, degree=4
# MAE=13216.52 | MSE=248939223.88 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=2.5000000000000004, degree=5
# MAE=12329.98 | MSE=324441237.76 | RMSE=18012.25
# SVR(kernel=poly, C=0.01, gamma=2.6, degree=1
# MAE=10520.45 | MSE=245698653.81 | RMSE=15674.78
# SVR(kernel=poly, C=0.01, gamma=2.6, degree=2
# MAE=12643.05 | MSE=227348826.25 | RMSE=15078.09
# SVR(kernel=poly, C=0.01, gamma=2.6, degree=3
# MAE=11814.42 | MSE=312333408.37 | RMSE=17672.96
# SVR(kernel=poly, C=0.01, gamma=2.6, degree=4
# MAE=13216.49 | MSE=248932795.76 | RMSE=15777.60
# SVR(kernel=poly, C=0.01, gamma=2.6, degree=5
# MAE=12330.12 | MSE=324415989.45 | RMSE=18011.55
# SVR(kernel=poly, C=0.01, gamma=2.7, degree=1
# MAE=10520.52 | MSE=245707785.34 | RMSE=15675.07
# SVR(kernel=poly, C=0.01, gamma=2.7, degree=2
# MAE=12643.06 | MSE=227346407.64 | RMSE=15078.01
# SVR(kernel=poly, C=0.01, gamma=2.7, degree=3
# MAE=11814.41 | MSE=312262502.40 | RMSE=17670.95
# SVR(kernel=poly, C=0.01, gamma=2.7, degree=4
# MAE=13216.52 | MSE=248939365.69 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=2.7, degree=5
# MAE=12329.97 | MSE=324432749.49 | RMSE=18012.02
# SVR(kernel=poly, C=0.01, gamma=2.8000000000000003, degree=1
# MAE=10520.52 | MSE=245707814.07 | RMSE=15675.07
# SVR(kernel=poly, C=0.01, gamma=2.8000000000000003, degree=2
# MAE=12643.06 | MSE=227346123.49 | RMSE=15078.00
# SVR(kernel=poly, C=0.01, gamma=2.8000000000000003, degree=3
# MAE=11814.35 | MSE=312286756.72 | RMSE=17671.64
# SVR(kernel=poly, C=0.01, gamma=2.8000000000000003, degree=4
# MAE=13216.52 | MSE=248939063.21 | RMSE=15777.80
# SVR(kernel=poly, C=0.01, gamma=2.8000000000000003, degree=5
# MAE=12330.19 | MSE=324395418.20 | RMSE=18010.98
# SVR(kernel=poly, C=0.01, gamma=2.9000000000000004, degree=1
# MAE=10520.61 | MSE=245693135.98 | RMSE=15674.60
# SVR(kernel=poly, C=0.01, gamma=2.9000000000000004, degree=2
# MAE=12643.06 | MSE=227346119.94 | RMSE=15078.00
# SVR(kernel=poly, C=0.01, gamma=2.9000000000000004, degree=3
# MAE=11814.17 | MSE=312272508.35 | RMSE=17671.23
# SVR(kernel=poly, C=0.01, gamma=2.9000000000000004, degree=4
# MAE=13216.50 | MSE=248931224.08 | RMSE=15777.55
# SVR(kernel=poly, C=0.01, gamma=2.9000000000000004, degree=5
# MAE=12330.30 | MSE=324378317.46 | RMSE=18010.51
# SVR(kernel=poly, C=0.01, gamma=3.0000000000000004, degree=1
# MAE=10519.95 | MSE=245456112.44 | RMSE=15667.04
# SVR(kernel=poly, C=0.01, gamma=3.0000000000000004, degree=2
# MAE=12642.99 | MSE=227364439.03 | RMSE=15078.61
# SVR(kernel=poly, C=0.01, gamma=3.0000000000000004, degree=3
# MAE=11814.30 | MSE=312283201.30 | RMSE=17671.54
# SVR(kernel=poly, C=0.01, gamma=3.0000000000000004, degree=4
# MAE=13216.52 | MSE=248939293.06 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=3.0000000000000004, degree=5
# MAE=12329.97 | MSE=324433516.97 | RMSE=18012.04
# SVR(kernel=poly, C=0.01, gamma=3.1, degree=1
# MAE=10520.16 | MSE=245422668.10 | RMSE=15665.97
# SVR(kernel=poly, C=0.01, gamma=3.1, degree=2
# MAE=12642.95 | MSE=227374861.96 | RMSE=15078.95
# SVR(kernel=poly, C=0.01, gamma=3.1, degree=3
# MAE=11814.30 | MSE=312283325.52 | RMSE=17671.54
# SVR(kernel=poly, C=0.01, gamma=3.1, degree=4
# MAE=13216.52 | MSE=248939377.64 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=3.1, degree=5
# MAE=12329.95 | MSE=324439333.66 | RMSE=18012.20
# SVR(kernel=poly, C=0.01, gamma=3.2, degree=1
# MAE=10520.49 | MSE=245461581.95 | RMSE=15667.21
# SVR(kernel=poly, C=0.01, gamma=3.2, degree=2
# MAE=12642.88 | MSE=227392844.48 | RMSE=15079.55
# SVR(kernel=poly, C=0.01, gamma=3.2, degree=3
# MAE=11814.28 | MSE=312302864.54 | RMSE=17672.09
# SVR(kernel=poly, C=0.01, gamma=3.2, degree=4
# MAE=13216.50 | MSE=248931164.66 | RMSE=15777.55
# SVR(kernel=poly, C=0.01, gamma=3.2, degree=5
# MAE=12329.98 | MSE=324440259.59 | RMSE=18012.23
# SVR(kernel=poly, C=0.01, gamma=3.3000000000000003, degree=1
# MAE=10520.49 | MSE=245461577.67 | RMSE=15667.21
# SVR(kernel=poly, C=0.01, gamma=3.3000000000000003, degree=2
# MAE=12642.87 | MSE=227395153.11 | RMSE=15079.63
# SVR(kernel=poly, C=0.01, gamma=3.3000000000000003, degree=3
# MAE=11814.12 | MSE=312318402.30 | RMSE=17672.53
# SVR(kernel=poly, C=0.01, gamma=3.3000000000000003, degree=4
# MAE=13216.52 | MSE=248939157.13 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=3.3000000000000003, degree=5
# MAE=12330.25 | MSE=324388383.97 | RMSE=18010.79
# SVR(kernel=poly, C=0.01, gamma=3.4000000000000004, degree=1
# MAE=10519.95 | MSE=245456115.21 | RMSE=15667.04
# SVR(kernel=poly, C=0.01, gamma=3.4000000000000004, degree=2
# MAE=12642.88 | MSE=227392835.67 | RMSE=15079.55
# SVR(kernel=poly, C=0.01, gamma=3.4000000000000004, degree=3
# MAE=11814.16 | MSE=312272900.34 | RMSE=17671.25
# SVR(kernel=poly, C=0.01, gamma=3.4000000000000004, degree=4
# MAE=13216.56 | MSE=248959308.47 | RMSE=15778.44
# SVR(kernel=poly, C=0.01, gamma=3.4000000000000004, degree=5
# MAE=12330.29 | MSE=324397006.24 | RMSE=18011.02
# SVR(kernel=poly, C=0.01, gamma=3.5000000000000004, degree=1
# MAE=10520.35 | MSE=245391163.31 | RMSE=15664.97
# SVR(kernel=poly, C=0.01, gamma=3.5000000000000004, degree=2
# MAE=12642.83 | MSE=227406060.98 | RMSE=15079.99
# SVR(kernel=poly, C=0.01, gamma=3.5000000000000004, degree=3
# MAE=11814.39 | MSE=312257120.00 | RMSE=17670.80
# SVR(kernel=poly, C=0.01, gamma=3.5000000000000004, degree=4
# MAE=13216.47 | MSE=248924504.18 | RMSE=15777.34
# SVR(kernel=poly, C=0.01, gamma=3.5000000000000004, degree=5
# MAE=12329.97 | MSE=324459294.52 | RMSE=18012.75
# SVR(kernel=poly, C=0.01, gamma=3.6, degree=1
# MAE=10519.95 | MSE=245456112.13 | RMSE=15667.04
# SVR(kernel=poly, C=0.01, gamma=3.6, degree=2
# MAE=12642.21 | MSE=227625351.94 | RMSE=15087.26
# SVR(kernel=poly, C=0.01, gamma=3.6, degree=3
# MAE=11814.30 | MSE=312283351.61 | RMSE=17671.54
# SVR(kernel=poly, C=0.01, gamma=3.6, degree=4
# MAE=13216.45 | MSE=248917731.61 | RMSE=15777.13
# SVR(kernel=poly, C=0.01, gamma=3.6, degree=5
# MAE=12330.14 | MSE=324389837.55 | RMSE=18010.83
# SVR(kernel=poly, C=0.01, gamma=3.7, degree=1
# MAE=10518.89 | MSE=245488605.50 | RMSE=15668.08
# SVR(kernel=poly, C=0.01, gamma=3.7, degree=2
# MAE=12642.21 | MSE=227625357.68 | RMSE=15087.26
# SVR(kernel=poly, C=0.01, gamma=3.7, degree=3
# MAE=11814.39 | MSE=312257806.21 | RMSE=17670.82
# SVR(kernel=poly, C=0.01, gamma=3.7, degree=4
# MAE=13216.52 | MSE=248938833.93 | RMSE=15777.80
# SVR(kernel=poly, C=0.01, gamma=3.7, degree=5
# MAE=12330.31 | MSE=324376372.23 | RMSE=18010.45
# SVR(kernel=poly, C=0.01, gamma=3.8000000000000003, degree=1
# MAE=10519.89 | MSE=245425495.98 | RMSE=15666.06
# SVR(kernel=poly, C=0.01, gamma=3.8000000000000003, degree=2
# MAE=12642.21 | MSE=227625353.61 | RMSE=15087.26
# SVR(kernel=poly, C=0.01, gamma=3.8000000000000003, degree=3
# MAE=11814.39 | MSE=312257221.57 | RMSE=17670.80
# SVR(kernel=poly, C=0.01, gamma=3.8000000000000003, degree=4
# MAE=13216.47 | MSE=248925210.58 | RMSE=15777.36
# SVR(kernel=poly, C=0.01, gamma=3.8000000000000003, degree=5
# MAE=12329.92 | MSE=324462489.06 | RMSE=18012.84
# SVR(kernel=poly, C=0.01, gamma=3.9000000000000004, degree=1
# MAE=10520.32 | MSE=245355964.92 | RMSE=15663.84
# SVR(kernel=poly, C=0.01, gamma=3.9000000000000004, degree=2
# MAE=12642.21 | MSE=227625360.07 | RMSE=15087.26
# SVR(kernel=poly, C=0.01, gamma=3.9000000000000004, degree=3
# MAE=11814.39 | MSE=312257015.73 | RMSE=17670.80
# SVR(kernel=poly, C=0.01, gamma=3.9000000000000004, degree=4
# MAE=13216.47 | MSE=248923001.77 | RMSE=15777.29
# SVR(kernel=poly, C=0.01, gamma=3.9000000000000004, degree=5
# MAE=12329.95 | MSE=324433074.99 | RMSE=18012.03
# SVR(kernel=poly, C=0.01, gamma=4.0, degree=1
# MAE=10520.32 | MSE=245355964.30 | RMSE=15663.84
# SVR(kernel=poly, C=0.01, gamma=4.0, degree=2
# MAE=12642.21 | MSE=227625346.37 | RMSE=15087.26
# SVR(kernel=poly, C=0.01, gamma=4.0, degree=3
# MAE=11814.30 | MSE=312283484.86 | RMSE=17671.54
# SVR(kernel=poly, C=0.01, gamma=4.0, degree=4
# MAE=13216.47 | MSE=248925069.94 | RMSE=15777.36
# SVR(kernel=poly, C=0.01, gamma=4.0, degree=5
# MAE=12329.68 | MSE=324447570.56 | RMSE=18012.43
# SVR(kernel=poly, C=0.01, gamma=4.1, degree=1
# MAE=10520.17 | MSE=245455188.31 | RMSE=15667.01
# SVR(kernel=poly, C=0.01, gamma=4.1, degree=2
# MAE=12642.21 | MSE=227625352.29 | RMSE=15087.26
# SVR(kernel=poly, C=0.01, gamma=4.1, degree=3
# MAE=11814.32 | MSE=312278286.08 | RMSE=17671.40
# SVR(kernel=poly, C=0.01, gamma=4.1, degree=4
# MAE=13216.52 | MSE=248939204.07 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=4.1, degree=5
# MAE=12329.92 | MSE=324518052.75 | RMSE=18014.38
# SVR(kernel=poly, C=0.01, gamma=4.2, degree=1
# MAE=10519.89 | MSE=245425497.87 | RMSE=15666.06
# SVR(kernel=poly, C=0.01, gamma=4.2, degree=2
# MAE=12642.21 | MSE=227625357.77 | RMSE=15087.26
# SVR(kernel=poly, C=0.01, gamma=4.2, degree=3
# MAE=11814.08 | MSE=312304584.35 | RMSE=17672.14
# SVR(kernel=poly, C=0.01, gamma=4.2, degree=4
# MAE=13216.49 | MSE=248933734.72 | RMSE=15777.63
# SVR(kernel=poly, C=0.01, gamma=4.2, degree=5
# MAE=12329.72 | MSE=324478877.24 | RMSE=18013.30
# SVR(kernel=poly, C=0.01, gamma=4.3, degree=1
# MAE=10519.89 | MSE=245425494.56 | RMSE=15666.06
# SVR(kernel=poly, C=0.01, gamma=4.3, degree=2
# MAE=12642.22 | MSE=227623374.52 | RMSE=15087.19
# SVR(kernel=poly, C=0.01, gamma=4.3, degree=3
# MAE=11814.16 | MSE=312272689.52 | RMSE=17671.24
# SVR(kernel=poly, C=0.01, gamma=4.3, degree=4
# MAE=13216.47 | MSE=248923167.49 | RMSE=15777.30
# SVR(kernel=poly, C=0.01, gamma=4.3, degree=5
# MAE=12330.33 | MSE=324382404.14 | RMSE=18010.62
# SVR(kernel=poly, C=0.01, gamma=4.3999999999999995, degree=1
# MAE=10520.32 | MSE=245355966.24 | RMSE=15663.84
# SVR(kernel=poly, C=0.01, gamma=4.3999999999999995, degree=2
# MAE=12642.22 | MSE=227623363.68 | RMSE=15087.19
# SVR(kernel=poly, C=0.01, gamma=4.3999999999999995, degree=3
# MAE=11814.39 | MSE=312257700.78 | RMSE=17670.81
# SVR(kernel=poly, C=0.01, gamma=4.3999999999999995, degree=4
# MAE=13216.52 | MSE=248939700.30 | RMSE=15777.82
# SVR(kernel=poly, C=0.01, gamma=4.3999999999999995, degree=5
# MAE=12330.16 | MSE=324430001.94 | RMSE=18011.94
# SVR(kernel=poly, C=0.01, gamma=4.5, degree=1
# MAE=10519.89 | MSE=245425487.60 | RMSE=15666.06
# SVR(kernel=poly, C=0.01, gamma=4.5, degree=2
# MAE=12642.19 | MSE=227644707.42 | RMSE=15087.90
# SVR(kernel=poly, C=0.01, gamma=4.5, degree=3
# MAE=11814.16 | MSE=312307733.86 | RMSE=17672.23
# SVR(kernel=poly, C=0.01, gamma=4.5, degree=4
# MAE=13216.47 | MSE=248924383.07 | RMSE=15777.34
# SVR(kernel=poly, C=0.01, gamma=4.5, degree=5
# MAE=12330.15 | MSE=324394644.71 | RMSE=18010.96
# SVR(kernel=poly, C=0.01, gamma=4.6, degree=1
# MAE=10520.40 | MSE=245355106.42 | RMSE=15663.82
# SVR(kernel=poly, C=0.01, gamma=4.6, degree=2
# MAE=12642.18 | MSE=227648034.92 | RMSE=15088.01
# SVR(kernel=poly, C=0.01, gamma=4.6, degree=3
# MAE=11814.30 | MSE=312283301.47 | RMSE=17671.54
# SVR(kernel=poly, C=0.01, gamma=4.6, degree=4
# MAE=13216.49 | MSE=248933055.20 | RMSE=15777.61
# SVR(kernel=poly, C=0.01, gamma=4.6, degree=5
# MAE=12329.48 | MSE=324518063.89 | RMSE=18014.38
# SVR(kernel=poly, C=0.01, gamma=4.7, degree=1
# MAE=10519.92 | MSE=245429376.70 | RMSE=15666.19
# SVR(kernel=poly, C=0.01, gamma=4.7, degree=2
# MAE=12642.22 | MSE=227623361.39 | RMSE=15087.19
# SVR(kernel=poly, C=0.01, gamma=4.7, degree=3
# MAE=11814.28 | MSE=312272883.60 | RMSE=17671.24
# SVR(kernel=poly, C=0.01, gamma=4.7, degree=4
# MAE=13216.52 | MSE=248939312.63 | RMSE=15777.81
# SVR(kernel=poly, C=0.01, gamma=4.7, degree=5
# MAE=12329.81 | MSE=324444890.40 | RMSE=18012.35
# SVR(kernel=poly, C=0.01, gamma=4.8, degree=1
# MAE=10520.32 | MSE=245355965.84 | RMSE=15663.84
# SVR(kernel=poly, C=0.01, gamma=4.8, degree=2
# MAE=12642.22 | MSE=227623371.15 | RMSE=15087.19
# SVR(kernel=poly, C=0.01, gamma=4.8, degree=3
# MAE=11814.49 | MSE=312270456.43 | RMSE=17671.18
# SVR(kernel=poly, C=0.01, gamma=4.8, degree=4
# MAE=13216.47 | MSE=248925483.49 | RMSE=15777.37
# SVR(kernel=poly, C=0.01, gamma=4.8, degree=5
# MAE=12330.50 | MSE=324303450.97 | RMSE=18008.43
# SVR(kernel=poly, C=0.01, gamma=4.9, degree=1
# MAE=10519.49 | MSE=245333795.84 | RMSE=15663.13
# SVR(kernel=poly, C=0.01, gamma=4.9, degree=2
# MAE=12642.21 | MSE=227631733.45 | RMSE=15087.47
# SVR(kernel=poly, C=0.01, gamma=4.9, degree=3
# MAE=11814.06 | MSE=312304837.97 | RMSE=17672.15
# SVR(kernel=poly, C=0.01, gamma=4.9, degree=4
# MAE=13216.46 | MSE=248922627.39 | RMSE=15777.28
# SVR(kernel=poly, C=0.01, gamma=4.9, degree=5
# MAE=12330.50 | MSE=324343407.81 | RMSE=18009.54
# SVR(kernel=poly, C=0.11, gamma=0.1, degree=1
# MAE=10520.54 | MSE=247174585.54 | RMSE=15721.79
# SVR(kernel=poly, C=0.11, gamma=0.1, degree=2
# MAE=13219.14 | MSE=250459551.07 | RMSE=15825.91
# SVR(kernel=poly, C=0.11, gamma=0.1, degree=3
# MAE=12089.52 | MSE=318416248.61 | RMSE=17844.22
# SVR(kernel=poly, C=0.11, gamma=0.1, degree=4
# MAE=13871.27 | MSE=306089347.39 | RMSE=17495.41
# SVR(kernel=poly, C=0.11, gamma=0.1, degree=5
# MAE=13804.37 | MSE=311545168.21 | RMSE=17650.64
# SVR(kernel=poly, C=0.11, gamma=0.2, degree=1
# MAE=10519.82 | MSE=245863271.49 | RMSE=15680.03
# SVR(kernel=poly, C=0.11, gamma=0.2, degree=2
# MAE=12730.01 | MSE=225236683.23 | RMSE=15007.89
# SVR(kernel=poly, C=0.11, gamma=0.2, degree=3
# MAE=11826.68 | MSE=312331447.05 | RMSE=17672.90
# SVR(kernel=poly, C=0.11, gamma=0.2, degree=4
# MAE=13500.87 | MSE=274390171.12 | RMSE=16564.73
# SVR(kernel=poly, C=0.11, gamma=0.2, degree=5
# MAE=12414.52 | MSE=328222337.13 | RMSE=18116.91
# SVR(kernel=poly, C=0.11, gamma=0.30000000000000004, degree=1
# MAE=10520.49 | MSE=245461584.02 | RMSE=15667.21
# SVR(kernel=poly, C=0.11, gamma=0.30000000000000004, degree=2
# MAE=12663.99 | MSE=225815814.45 | RMSE=15027.17
# SVR(kernel=poly, C=0.11, gamma=0.30000000000000004, degree=3
# MAE=11818.36 | MSE=312336895.58 | RMSE=17673.06
# SVR(kernel=poly, C=0.11, gamma=0.30000000000000004, degree=4
# MAE=13237.48 | MSE=252007376.56 | RMSE=15874.74
# SVR(kernel=poly, C=0.11, gamma=0.30000000000000004, degree=5
# MAE=12327.00 | MSE=325816069.34 | RMSE=18050.38
# SVR(kernel=poly, C=0.11, gamma=0.4, degree=1
# MAE=10520.32 | MSE=245355965.15 | RMSE=15663.84
# SVR(kernel=poly, C=0.11, gamma=0.4, degree=2
# MAE=12649.17 | MSE=226572826.37 | RMSE=15052.34
# SVR(kernel=poly, C=0.11, gamma=0.4, degree=3
# MAE=11814.72 | MSE=312645901.21 | RMSE=17681.80
# SVR(kernel=poly, C=0.11, gamma=0.4, degree=4
# MAE=13217.06 | MSE=249465185.44 | RMSE=15794.47
# SVR(kernel=poly, C=0.11, gamma=0.4, degree=5
# MAE=12328.38 | MSE=324768270.01 | RMSE=18021.33
# SVR(kernel=poly, C=0.11, gamma=0.5, degree=1
# MAE=10519.49 | MSE=245333790.80 | RMSE=15663.13
# SVR(kernel=poly, C=0.11, gamma=0.5, degree=2
# MAE=12645.06 | MSE=226979598.19 | RMSE=15065.84
# SVR(kernel=poly, C=0.11, gamma=0.5, degree=3
# MAE=11814.46 | MSE=312500843.75 | RMSE=17677.69
# SVR(kernel=poly, C=0.11, gamma=0.5, degree=4
# MAE=13216.29 | MSE=249216375.83 | RMSE=15786.59
# SVR(kernel=poly, C=0.11, gamma=0.5, degree=5
# MAE=12328.77 | MSE=324787362.37 | RMSE=18021.86
# SVR(kernel=poly, C=0.11, gamma=0.6, degree=1
# MAE=10519.49 | MSE=245333786.23 | RMSE=15663.13
# SVR(kernel=poly, C=0.11, gamma=0.6, degree=2
# MAE=12644.24 | MSE=227095901.60 | RMSE=15069.70
# SVR(kernel=poly, C=0.11, gamma=0.6, degree=3
# MAE=11814.52 | MSE=312522090.69 | RMSE=17678.29
# SVR(kernel=poly, C=0.11, gamma=0.6, degree=4
# MAE=13216.25 | MSE=249125267.40 | RMSE=15783.70
# SVR(kernel=poly, C=0.11, gamma=0.6, degree=5
# MAE=12328.77 | MSE=324787317.44 | RMSE=18021.86
# SVR(kernel=poly, C=0.11, gamma=0.7000000000000001, degree=1
# MAE=10519.49 | MSE=245333792.87 | RMSE=15663.13
# SVR(kernel=poly, C=0.11, gamma=0.7000000000000001, degree=2
# MAE=12643.77 | MSE=227181533.37 | RMSE=15072.54
# SVR(kernel=poly, C=0.11, gamma=0.7000000000000001, degree=3
# MAE=11814.64 | MSE=312190801.85 | RMSE=17668.92
# SVR(kernel=poly, C=0.11, gamma=0.7000000000000001, degree=4
# MAE=13215.77 | MSE=248878655.72 | RMSE=15775.89
# SVR(kernel=poly, C=0.11, gamma=0.7000000000000001, degree=5
# MAE=12330.39 | MSE=324363582.85 | RMSE=18010.10
# SVR(kernel=poly, C=0.11, gamma=0.8, degree=1
# MAE=10519.30 | MSE=245313493.86 | RMSE=15662.49
# SVR(kernel=poly, C=0.11, gamma=0.8, degree=2
# MAE=12643.08 | MSE=227338899.11 | RMSE=15077.76
# SVR(kernel=poly, C=0.11, gamma=0.8, degree=3
# MAE=11814.04 | MSE=312344427.05 | RMSE=17673.27
# SVR(kernel=poly, C=0.11, gamma=0.8, degree=4
# MAE=13215.77 | MSE=248878663.99 | RMSE=15775.89
# SVR(kernel=poly, C=0.11, gamma=0.8, degree=5
# MAE=12329.99 | MSE=324436968.52 | RMSE=18012.13
# SVR(kernel=poly, C=0.11, gamma=0.9, degree=1
# MAE=10518.94 | MSE=245299129.29 | RMSE=15662.03
# SVR(kernel=poly, C=0.11, gamma=0.9, degree=2
# MAE=12643.06 | MSE=227346121.74 | RMSE=15078.00
# SVR(kernel=poly, C=0.11, gamma=0.9, degree=3
# MAE=11814.40 | MSE=312294679.11 | RMSE=17671.86
# SVR(kernel=poly, C=0.11, gamma=0.9, degree=4
# MAE=13216.50 | MSE=248931144.40 | RMSE=15777.55
# SVR(kernel=poly, C=0.11, gamma=0.9, degree=5
# MAE=12329.98 | MSE=324436836.31 | RMSE=18012.13
# SVR(kernel=poly, C=0.11, gamma=1.0, degree=1
# MAE=10519.72 | MSE=245330463.72 | RMSE=15663.03
# SVR(kernel=poly, C=0.11, gamma=1.0, degree=2
# MAE=12642.88 | MSE=227392841.96 | RMSE=15079.55
# SVR(kernel=poly, C=0.11, gamma=1.0, degree=3
# MAE=11814.39 | MSE=312258874.45 | RMSE=17670.85
# SVR(kernel=poly, C=0.11, gamma=1.0, degree=4
# MAE=13216.52 | MSE=248939221.03 | RMSE=15777.81
# SVR(kernel=poly, C=0.11, gamma=1.0, degree=5
# MAE=12329.99 | MSE=324436221.76 | RMSE=18012.11
# SVR(kernel=poly, C=0.11, gamma=1.1, degree=1
# MAE=10519.29 | MSE=245313494.13 | RMSE=15662.49
# SVR(kernel=poly, C=0.11, gamma=1.1, degree=2
# MAE=12642.21 | MSE=227625353.04 | RMSE=15087.26
# SVR(kernel=poly, C=0.11, gamma=1.1, degree=3
# MAE=11814.39 | MSE=312257733.58 | RMSE=17670.82
# SVR(kernel=poly, C=0.11, gamma=1.1, degree=4
# MAE=13216.52 | MSE=248939253.06 | RMSE=15777.81
# SVR(kernel=poly, C=0.11, gamma=1.1, degree=5
# MAE=12329.99 | MSE=324437024.05 | RMSE=18012.14
# SVR(kernel=poly, C=0.11, gamma=1.2000000000000002, degree=1
# MAE=10519.29 | MSE=245313508.55 | RMSE=15662.49
# SVR(kernel=poly, C=0.11, gamma=1.2000000000000002, degree=2
# MAE=12642.21 | MSE=227625355.25 | RMSE=15087.26
# SVR(kernel=poly, C=0.11, gamma=1.2000000000000002, degree=3
# MAE=11814.12 | MSE=312303050.20 | RMSE=17672.10
# SVR(kernel=poly, C=0.11, gamma=1.2000000000000002, degree=4
# MAE=13216.52 | MSE=248939202.62 | RMSE=15777.81
# SVR(kernel=poly, C=0.11, gamma=1.2000000000000002, degree=5
# MAE=12329.63 | MSE=324510206.25 | RMSE=18014.17
# SVR(kernel=poly, C=0.11, gamma=1.3000000000000003, degree=1
# MAE=10519.30 | MSE=245313495.50 | RMSE=15662.49
# SVR(kernel=poly, C=0.11, gamma=1.3000000000000003, degree=2
# MAE=12642.22 | MSE=227623366.08 | RMSE=15087.19
# ...
# MAE=12330.01 | MSE=324437888.39 | RMSE=18012.16
# SVR(kernel=poly, C=0.11, gamma=1.8000000000000003, degree=1
# MAE=10520.34 | MSE=244774547.15 | RMSE=15645.27
# SVR(kernel=poly, C=0.11, gamma=1.8000000000000003, degree=2
# MAE=12642.07 | MSE=227751494.16 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=1.8000000000000003, degree=3
# MAE=11814.45 | MSE=312268667.28 | RMSE=17671.13
# SVR(kernel=poly, C=0.11, gamma=1.8000000000000003, degree=4
# MAE=13216.52 | MSE=248939311.16 | RMSE=15777.81
# SVR(kernel=poly, C=0.11, gamma=1.8000000000000003, degree=5
# MAE=12329.97 | MSE=324433871.53 | RMSE=18012.05
# SVR(kernel=poly, C=0.11, gamma=1.9000000000000001, degree=1
# MAE=10520.54 | MSE=244545847.67 | RMSE=15637.96
# SVR(kernel=poly, C=0.11, gamma=1.9000000000000001, degree=2
# MAE=12642.07 | MSE=227751482.53 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=1.9000000000000001, degree=3
# MAE=11814.39 | MSE=312257274.44 | RMSE=17670.80
# SVR(kernel=poly, C=0.11, gamma=1.9000000000000001, degree=4
# MAE=13216.50 | MSE=248934778.53 | RMSE=15777.67
# SVR(kernel=poly, C=0.11, gamma=1.9000000000000001, degree=5
# MAE=12329.96 | MSE=324445716.71 | RMSE=18012.38
# SVR(kernel=poly, C=0.11, gamma=2.0, degree=1
# MAE=10520.54 | MSE=244545889.90 | RMSE=15637.96
# SVR(kernel=poly, C=0.11, gamma=2.0, degree=2
# MAE=12642.09 | MSE=227750082.23 | RMSE=15091.39
# SVR(kernel=poly, C=0.11, gamma=2.0, degree=3
# MAE=11814.30 | MSE=312283540.26 | RMSE=17671.55
# SVR(kernel=poly, C=0.11, gamma=2.0, degree=4
# MAE=13216.47 | MSE=248924862.75 | RMSE=15777.35
# SVR(kernel=poly, C=0.11, gamma=2.0, degree=5
# MAE=12330.04 | MSE=324403895.38 | RMSE=18011.22
# SVR(kernel=poly, C=0.11, gamma=2.1, degree=1
# MAE=10520.54 | MSE=244545947.12 | RMSE=15637.96
# SVR(kernel=poly, C=0.11, gamma=2.1, degree=2
# MAE=12642.07 | MSE=227751494.87 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=2.1, degree=3
# MAE=11814.16 | MSE=312273084.42 | RMSE=17671.25
# SVR(kernel=poly, C=0.11, gamma=2.1, degree=4
# MAE=13216.51 | MSE=248938700.21 | RMSE=15777.79
# SVR(kernel=poly, C=0.11, gamma=2.1, degree=5
# MAE=12330.16 | MSE=324401008.74 | RMSE=18011.14
# SVR(kernel=poly, C=0.11, gamma=2.2, degree=1
# MAE=10520.49 | MSE=244607751.82 | RMSE=15639.94
# SVR(kernel=poly, C=0.11, gamma=2.2, degree=2
# MAE=12642.07 | MSE=227751467.90 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=2.2, degree=3
# MAE=11814.39 | MSE=312257087.26 | RMSE=17670.80
# SVR(kernel=poly, C=0.11, gamma=2.2, degree=4
# MAE=13216.50 | MSE=248931534.42 | RMSE=15777.56
# SVR(kernel=poly, C=0.11, gamma=2.2, degree=5
# MAE=12330.00 | MSE=324439895.24 | RMSE=18012.22
# SVR(kernel=poly, C=0.11, gamma=2.3000000000000003, degree=1
# MAE=10520.39 | MSE=244715945.34 | RMSE=15643.40
# SVR(kernel=poly, C=0.11, gamma=2.3000000000000003, degree=2
# MAE=12642.06 | MSE=227755123.31 | RMSE=15091.56
# SVR(kernel=poly, C=0.11, gamma=2.3000000000000003, degree=3
# MAE=11814.28 | MSE=312301966.54 | RMSE=17672.07
# SVR(kernel=poly, C=0.11, gamma=2.3000000000000003, degree=4
# MAE=13216.49 | MSE=248934071.53 | RMSE=15777.64
# SVR(kernel=poly, C=0.11, gamma=2.3000000000000003, degree=5
# MAE=12329.96 | MSE=324425958.97 | RMSE=18011.83
# SVR(kernel=poly, C=0.11, gamma=2.4000000000000004, degree=1
# MAE=10520.54 | MSE=244545911.22 | RMSE=15637.96
# SVR(kernel=poly, C=0.11, gamma=2.4000000000000004, degree=2
# MAE=12642.07 | MSE=227751469.29 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=2.4000000000000004, degree=3
# MAE=11814.29 | MSE=312298268.35 | RMSE=17671.96
# SVR(kernel=poly, C=0.11, gamma=2.4000000000000004, degree=4
# MAE=13216.47 | MSE=248925804.50 | RMSE=15777.38
# SVR(kernel=poly, C=0.11, gamma=2.4000000000000004, degree=5
# MAE=12330.05 | MSE=324430341.07 | RMSE=18011.95
# SVR(kernel=poly, C=0.11, gamma=2.5000000000000004, degree=1
# MAE=10520.81 | MSE=244523918.16 | RMSE=15637.26
# SVR(kernel=poly, C=0.11, gamma=2.5000000000000004, degree=2
# MAE=12642.10 | MSE=227743437.44 | RMSE=15091.17
# SVR(kernel=poly, C=0.11, gamma=2.5000000000000004, degree=3
# MAE=11814.58 | MSE=312229796.54 | RMSE=17670.03
# SVR(kernel=poly, C=0.11, gamma=2.5000000000000004, degree=4
# MAE=13216.49 | MSE=248929965.50 | RMSE=15777.51
# SVR(kernel=poly, C=0.11, gamma=2.5000000000000004, degree=5
# MAE=12330.32 | MSE=324406048.81 | RMSE=18011.28
# SVR(kernel=poly, C=0.11, gamma=2.6, degree=1
# MAE=10520.38 | MSE=244731830.02 | RMSE=15643.91
# SVR(kernel=poly, C=0.11, gamma=2.6, degree=2
# MAE=12642.07 | MSE=227751471.79 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=2.6, degree=3
# MAE=11814.53 | MSE=312231422.20 | RMSE=17670.07
# SVR(kernel=poly, C=0.11, gamma=2.6, degree=4
# MAE=13216.52 | MSE=248938680.97 | RMSE=15777.79
# SVR(kernel=poly, C=0.11, gamma=2.6, degree=5
# MAE=12330.07 | MSE=324452746.05 | RMSE=18012.57
# SVR(kernel=poly, C=0.11, gamma=2.7, degree=1
# MAE=10520.54 | MSE=244545851.46 | RMSE=15637.96
# SVR(kernel=poly, C=0.11, gamma=2.7, degree=2
# MAE=12642.07 | MSE=227751471.96 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=2.7, degree=3
# MAE=11814.46 | MSE=312234452.32 | RMSE=17670.16
# SVR(kernel=poly, C=0.11, gamma=2.7, degree=4
# MAE=13216.46 | MSE=248921280.48 | RMSE=15777.24
# SVR(kernel=poly, C=0.11, gamma=2.7, degree=5
# MAE=12330.06 | MSE=324345102.28 | RMSE=18009.58
# SVR(kernel=poly, C=0.11, gamma=2.8000000000000003, degree=1
# MAE=10520.38 | MSE=244731102.82 | RMSE=15643.88
# SVR(kernel=poly, C=0.11, gamma=2.8000000000000003, degree=2
# MAE=12642.07 | MSE=227751492.40 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=2.8000000000000003, degree=3
# MAE=11814.08 | MSE=312332916.68 | RMSE=17672.94
# SVR(kernel=poly, C=0.11, gamma=2.8000000000000003, degree=4
# MAE=13216.45 | MSE=248922316.54 | RMSE=15777.27
# SVR(kernel=poly, C=0.11, gamma=2.8000000000000003, degree=5
# MAE=12330.05 | MSE=324445986.45 | RMSE=18012.38
# SVR(kernel=poly, C=0.11, gamma=2.9000000000000004, degree=1
# MAE=10520.53 | MSE=244533291.74 | RMSE=15637.56
# SVR(kernel=poly, C=0.11, gamma=2.9000000000000004, degree=2
# MAE=12642.09 | MSE=227750111.84 | RMSE=15091.39
# SVR(kernel=poly, C=0.11, gamma=2.9000000000000004, degree=3
# MAE=11814.40 | MSE=312255430.82 | RMSE=17670.75
# SVR(kernel=poly, C=0.11, gamma=2.9000000000000004, degree=4
# MAE=13216.49 | MSE=248934881.41 | RMSE=15777.67
# SVR(kernel=poly, C=0.11, gamma=2.9000000000000004, degree=5
# MAE=12330.05 | MSE=324384667.40 | RMSE=18010.68
# SVR(kernel=poly, C=0.11, gamma=3.0000000000000004, degree=1
# MAE=10520.63 | MSE=244534192.09 | RMSE=15637.59
# SVR(kernel=poly, C=0.11, gamma=3.0000000000000004, degree=2
# MAE=12642.07 | MSE=227751519.59 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=3.0000000000000004, degree=3
# MAE=11814.28 | MSE=312301653.09 | RMSE=17672.06
# SVR(kernel=poly, C=0.11, gamma=3.0000000000000004, degree=4
# MAE=13216.47 | MSE=248920685.88 | RMSE=15777.22
# SVR(kernel=poly, C=0.11, gamma=3.0000000000000004, degree=5
# MAE=12329.88 | MSE=324399423.76 | RMSE=18011.09
# SVR(kernel=poly, C=0.11, gamma=3.1, degree=1
# MAE=10520.27 | MSE=244594541.79 | RMSE=15639.52
# SVR(kernel=poly, C=0.11, gamma=3.1, degree=2
# MAE=12642.07 | MSE=227751527.83 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=3.1, degree=3
# MAE=11814.38 | MSE=312312721.21 | RMSE=17672.37
# SVR(kernel=poly, C=0.11, gamma=3.1, degree=4
# MAE=13216.48 | MSE=248926412.74 | RMSE=15777.40
# SVR(kernel=poly, C=0.11, gamma=3.1, degree=5
# MAE=12329.55 | MSE=324580748.10 | RMSE=18016.12
# SVR(kernel=poly, C=0.11, gamma=3.2, degree=1
# MAE=10520.54 | MSE=244547497.41 | RMSE=15638.01
# SVR(kernel=poly, C=0.11, gamma=3.2, degree=2
# MAE=12642.09 | MSE=227750083.50 | RMSE=15091.39
# SVR(kernel=poly, C=0.11, gamma=3.2, degree=3
# MAE=11814.22 | MSE=312300250.69 | RMSE=17672.02
# SVR(kernel=poly, C=0.11, gamma=3.2, degree=4
# MAE=13216.48 | MSE=248927199.79 | RMSE=15777.43
# SVR(kernel=poly, C=0.11, gamma=3.2, degree=5
# MAE=12330.04 | MSE=324454304.67 | RMSE=18012.62
# SVR(kernel=poly, C=0.11, gamma=3.3000000000000003, degree=1
# MAE=10520.28 | MSE=244592039.23 | RMSE=15639.44
# SVR(kernel=poly, C=0.11, gamma=3.3000000000000003, degree=2
# MAE=12642.07 | MSE=227751520.72 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=3.3000000000000003, degree=3
# MAE=11814.16 | MSE=312306532.63 | RMSE=17672.20
# SVR(kernel=poly, C=0.11, gamma=3.3000000000000003, degree=4
# MAE=13216.45 | MSE=248914709.29 | RMSE=15777.03
# SVR(kernel=poly, C=0.11, gamma=3.3000000000000003, degree=5
# MAE=12330.27 | MSE=324375729.13 | RMSE=18010.43
# SVR(kernel=poly, C=0.11, gamma=3.4000000000000004, degree=1
# MAE=10520.55 | MSE=244549239.76 | RMSE=15638.07
# SVR(kernel=poly, C=0.11, gamma=3.4000000000000004, degree=2
# MAE=12642.09 | MSE=227746726.93 | RMSE=15091.28
# SVR(kernel=poly, C=0.11, gamma=3.4000000000000004, degree=3
# MAE=11814.31 | MSE=312256314.60 | RMSE=17670.78
# SVR(kernel=poly, C=0.11, gamma=3.4000000000000004, degree=4
# MAE=13216.46 | MSE=248917992.61 | RMSE=15777.14
# SVR(kernel=poly, C=0.11, gamma=3.4000000000000004, degree=5
# MAE=12330.76 | MSE=324218038.96 | RMSE=18006.06
# SVR(kernel=poly, C=0.11, gamma=3.5000000000000004, degree=1
# MAE=10520.24 | MSE=244595266.69 | RMSE=15639.54
# SVR(kernel=poly, C=0.11, gamma=3.5000000000000004, degree=2
# MAE=12642.07 | MSE=227751492.10 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=3.5000000000000004, degree=3
# MAE=11814.36 | MSE=312252597.33 | RMSE=17670.67
# SVR(kernel=poly, C=0.11, gamma=3.5000000000000004, degree=4
# MAE=13216.45 | MSE=248925455.24 | RMSE=15777.37
# SVR(kernel=poly, C=0.11, gamma=3.5000000000000004, degree=5
# MAE=12329.71 | MSE=324509698.69 | RMSE=18014.15
# SVR(kernel=poly, C=0.11, gamma=3.6, degree=1
# MAE=10520.63 | MSE=244534137.96 | RMSE=15637.59
# SVR(kernel=poly, C=0.11, gamma=3.6, degree=2
# MAE=12642.07 | MSE=227751518.64 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=3.6, degree=3
# MAE=11814.34 | MSE=312309897.51 | RMSE=17672.29
# SVR(kernel=poly, C=0.11, gamma=3.6, degree=4
# MAE=13216.47 | MSE=248921580.93 | RMSE=15777.25
# SVR(kernel=poly, C=0.11, gamma=3.6, degree=5
# MAE=12329.74 | MSE=324381299.23 | RMSE=18010.59
# SVR(kernel=poly, C=0.11, gamma=3.7, degree=1
# MAE=10520.24 | MSE=244595211.75 | RMSE=15639.54
# SVR(kernel=poly, C=0.11, gamma=3.7, degree=2
# MAE=12642.07 | MSE=227751493.50 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=3.7, degree=3
# MAE=11814.39 | MSE=312258413.83 | RMSE=17670.84
# SVR(kernel=poly, C=0.11, gamma=3.7, degree=4
# MAE=13216.45 | MSE=248926398.05 | RMSE=15777.40
# SVR(kernel=poly, C=0.11, gamma=3.7, degree=5
# MAE=12329.97 | MSE=324353318.53 | RMSE=18009.81
# SVR(kernel=poly, C=0.11, gamma=3.8000000000000003, degree=1
# MAE=10520.24 | MSE=244595199.51 | RMSE=15639.54
# SVR(kernel=poly, C=0.11, gamma=3.8000000000000003, degree=2
# MAE=12642.07 | MSE=227751777.33 | RMSE=15091.45
# SVR(kernel=poly, C=0.11, gamma=3.8000000000000003, degree=3
# MAE=11814.39 | MSE=312258631.20 | RMSE=17670.84
# SVR(kernel=poly, C=0.11, gamma=3.8000000000000003, degree=4
# MAE=13216.44 | MSE=248901680.99 | RMSE=15776.62
# SVR(kernel=poly, C=0.11, gamma=3.8000000000000003, degree=5
# MAE=12329.41 | MSE=324624924.08 | RMSE=18017.35
# SVR(kernel=poly, C=0.11, gamma=3.9000000000000004, degree=1
# MAE=10520.63 | MSE=244534181.85 | RMSE=15637.59
# SVR(kernel=poly, C=0.11, gamma=3.9000000000000004, degree=2
# MAE=12642.07 | MSE=227751420.87 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=3.9000000000000004, degree=3
# MAE=11814.51 | MSE=312232470.23 | RMSE=17670.10
# SVR(kernel=poly, C=0.11, gamma=3.9000000000000004, degree=4
# MAE=13216.47 | MSE=248908969.61 | RMSE=15776.85
# SVR(kernel=poly, C=0.11, gamma=3.9000000000000004, degree=5
# MAE=12330.18 | MSE=324250874.03 | RMSE=18006.97
# SVR(kernel=poly, C=0.11, gamma=4.0, degree=1
# MAE=10520.55 | MSE=244549254.94 | RMSE=15638.07
# SVR(kernel=poly, C=0.11, gamma=4.0, degree=2
# MAE=12642.07 | MSE=227768719.61 | RMSE=15092.01
# SVR(kernel=poly, C=0.11, gamma=4.0, degree=3
# MAE=11814.36 | MSE=312304603.31 | RMSE=17672.14
# SVR(kernel=poly, C=0.11, gamma=4.0, degree=4
# MAE=13216.46 | MSE=248931716.77 | RMSE=15777.57
# SVR(kernel=poly, C=0.11, gamma=4.0, degree=5
# MAE=12331.01 | MSE=324172085.18 | RMSE=18004.78
# SVR(kernel=poly, C=0.11, gamma=4.1, degree=1
# MAE=10520.24 | MSE=244595232.20 | RMSE=15639.54
# SVR(kernel=poly, C=0.11, gamma=4.1, degree=2
# MAE=12642.07 | MSE=227751836.10 | RMSE=15091.45
# SVR(kernel=poly, C=0.11, gamma=4.1, degree=3
# MAE=11814.43 | MSE=312314806.67 | RMSE=17672.43
# SVR(kernel=poly, C=0.11, gamma=4.1, degree=4
# MAE=13216.47 | MSE=248922899.86 | RMSE=15777.29
# SVR(kernel=poly, C=0.11, gamma=4.1, degree=5
# MAE=12329.41 | MSE=324418958.62 | RMSE=18011.63
# SVR(kernel=poly, C=0.11, gamma=4.2, degree=1
# MAE=10520.63 | MSE=244534172.05 | RMSE=15637.59
# SVR(kernel=poly, C=0.11, gamma=4.2, degree=2
# MAE=12642.07 | MSE=227751514.46 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=4.2, degree=3
# MAE=11814.31 | MSE=312307362.84 | RMSE=17672.22
# SVR(kernel=poly, C=0.11, gamma=4.2, degree=4
# MAE=13216.40 | MSE=248923575.28 | RMSE=15777.31
# SVR(kernel=poly, C=0.11, gamma=4.2, degree=5
# MAE=12330.24 | MSE=324353447.02 | RMSE=18009.82
# SVR(kernel=poly, C=0.11, gamma=4.3, degree=1
# MAE=10520.63 | MSE=244534094.02 | RMSE=15637.59
# SVR(kernel=poly, C=0.11, gamma=4.3, degree=2
# MAE=12642.07 | MSE=227751582.82 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=4.3, degree=3
# MAE=11814.44 | MSE=312225066.96 | RMSE=17669.89
# SVR(kernel=poly, C=0.11, gamma=4.3, degree=4
# MAE=13216.45 | MSE=248910815.32 | RMSE=15776.91
# SVR(kernel=poly, C=0.11, gamma=4.3, degree=5
# MAE=12329.58 | MSE=324341653.52 | RMSE=18009.49
# SVR(kernel=poly, C=0.11, gamma=4.3999999999999995, degree=1
# MAE=10520.24 | MSE=244595223.92 | RMSE=15639.54
# SVR(kernel=poly, C=0.11, gamma=4.3999999999999995, degree=2
# MAE=12642.07 | MSE=227751412.30 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=4.3999999999999995, degree=3
# MAE=11814.11 | MSE=312322960.14 | RMSE=17672.66
# SVR(kernel=poly, C=0.11, gamma=4.3999999999999995, degree=4
# MAE=13216.38 | MSE=248895206.90 | RMSE=15776.41
# SVR(kernel=poly, C=0.11, gamma=4.3999999999999995, degree=5
# MAE=12331.16 | MSE=324113803.97 | RMSE=18003.16
# SVR(kernel=poly, C=0.11, gamma=4.5, degree=1
# MAE=10520.63 | MSE=244534208.17 | RMSE=15637.59
# SVR(kernel=poly, C=0.11, gamma=4.5, degree=2
# MAE=12642.07 | MSE=227751532.88 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=4.5, degree=3
# MAE=11814.46 | MSE=312267877.11 | RMSE=17671.10
# SVR(kernel=poly, C=0.11, gamma=4.5, degree=4
# MAE=13216.44 | MSE=248924167.51 | RMSE=15777.33
# SVR(kernel=poly, C=0.11, gamma=4.5, degree=5
# MAE=12328.56 | MSE=324693387.79 | RMSE=18019.25
# SVR(kernel=poly, C=0.11, gamma=4.6, degree=1
# MAE=10520.27 | MSE=244594563.26 | RMSE=15639.52
# SVR(kernel=poly, C=0.11, gamma=4.6, degree=2
# MAE=12642.09 | MSE=227750111.01 | RMSE=15091.39
# SVR(kernel=poly, C=0.11, gamma=4.6, degree=3
# MAE=11814.43 | MSE=312241240.70 | RMSE=17670.35
# SVR(kernel=poly, C=0.11, gamma=4.6, degree=4
# MAE=13216.42 | MSE=248922064.03 | RMSE=15777.26
# SVR(kernel=poly, C=0.11, gamma=4.6, degree=5
# MAE=12328.25 | MSE=324838886.23 | RMSE=18023.29
# SVR(kernel=poly, C=0.11, gamma=4.7, degree=1
# MAE=10520.27 | MSE=244594447.34 | RMSE=15639.52
# SVR(kernel=poly, C=0.11, gamma=4.7, degree=2
# MAE=12642.11 | MSE=227732428.58 | RMSE=15090.81
# SVR(kernel=poly, C=0.11, gamma=4.7, degree=3
# MAE=11814.33 | MSE=312272963.91 | RMSE=17671.25
# SVR(kernel=poly, C=0.11, gamma=4.7, degree=4
# MAE=13216.47 | MSE=248921412.01 | RMSE=15777.24
# SVR(kernel=poly, C=0.11, gamma=4.7, degree=5
# MAE=12329.06 | MSE=324769054.91 | RMSE=18021.35
# SVR(kernel=poly, C=0.11, gamma=4.8, degree=1
# MAE=10520.05 | MSE=244587904.22 | RMSE=15639.31
# SVR(kernel=poly, C=0.11, gamma=4.8, degree=2
# MAE=12642.07 | MSE=227751414.45 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=4.8, degree=3
# MAE=11814.29 | MSE=312288977.88 | RMSE=17671.70
# SVR(kernel=poly, C=0.11, gamma=4.8, degree=4
# MAE=13216.52 | MSE=248936238.84 | RMSE=15777.71
# SVR(kernel=poly, C=0.11, gamma=4.8, degree=5
# MAE=12327.92 | MSE=324964973.60 | RMSE=18026.78
# SVR(kernel=poly, C=0.11, gamma=4.9, degree=1
# MAE=10520.63 | MSE=244534175.45 | RMSE=15637.59
# SVR(kernel=poly, C=0.11, gamma=4.9, degree=2
# MAE=12642.07 | MSE=227751496.08 | RMSE=15091.44
# SVR(kernel=poly, C=0.11, gamma=4.9, degree=3
# MAE=11814.31 | MSE=312276333.97 | RMSE=17671.34
# SVR(kernel=poly, C=0.11, gamma=4.9, degree=4
# MAE=13216.33 | MSE=248892361.38 | RMSE=15776.32
# SVR(kernel=poly, C=0.11, gamma=4.9, degree=5
# MAE=12329.47 | MSE=324618585.75 | RMSE=18017.17

# %%
best_fit_model = stats_df[stats_df['RMSE'] == stats_df['RMSE'].min()].head(1)
best_fit_model
# Out:
#     kernel     C  gamma degree          MAE           MSE         RMSE
# 195    rbf  0.11    4.9      0  3321.325157  2.667707e+07  5164.984997

# %%
kernel = str(best_fit_model['kernel'].values[0])
C = float(best_fit_model['C'])
gamma = float(best_fit_model['gamma'])
degree = int(best_fit_model['degree'])

if(kernel == 'poly'):
    rgs = SVR(kernel=kernel, C=C, gamma=gamma, degree=degree)
else:
    rgs = SVR(kernel=kernel, C=C, gamma=gamma)

rgs.fit(x_scaled, y_scaled)
pred = rgs.predict(x_scaled)

pred
# Out:
# array([-1.06306904, -1.06484087, -1.06656591, ...,  0.26382109,
#         0.26787687,  0.27190099])

# %%
with open("../../../models/low/svr_model.pkl", "wb") as f:
        pickle.dump(rgs, f)
